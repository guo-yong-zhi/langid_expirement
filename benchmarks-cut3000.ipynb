# %%
# import Pkg; Pkg.add("Tables"); Pkg.add("MarkdownTables"); Pkg.add("DataFrames")

# %%
# using ProgressMeter
include("datasetloader.jl")
include("benchmark.jl")
# Out:
# showtable (generic function with 2 methods)

# %%
WV = WikiDataSet("corpus/wikipedia/test", langs=LANGS)
TV = TatoebaDataset("corpus/tatoeba", "tatoeba_test.txt", langs=LANGS)
# Out:
# 521469-element TatoebaDataset:
#              "Pardonu, permesu al mi indiki tri erarojn en la supra artikolo." => "epo"
#                                           "Mi veturigos vin al la flughaveno." => "epo"
#                                                                  "Kio mankas?" => "epo"
#                                             "Aĥ, kiam ili renkontiĝos denove?" => "epo"
#  "Kiam mi estis infano, mi pasigis multajn horojn legante sola en mia ĉambro." => "epo"
#                                               "Ŝajnas, ke la trajno malfruas." => "epo"
#                                                                 "Venu rapide!" => "epo"
#                                                    "Li montris al mi albumon." => "epo"
#                                                              "Estis du kukoj." => "epo"
#                                       "Mia filo scipovas jam nombri ĝis cent." => "epo"
#                                                                                ⋮
#                                                       "Tohle pivo je výborné." => "ces"
#                                               "Musíš se řídit matčinou radou." => "ces"
#                                              "Tom potvrdil všechno, co řekli." => "ces"
#                                                         "Byl obnoven pořádek." => "ces"
#                                               "Medvědi jsou velmi nebezpeční." => "ces"
#                                      "Buď vděčný za to, že můžeš být s Tomem." => "ces"
#                                                 "Neštěstí nechodí nikdy samo." => "ces"
#                                                     "Problémem nejsou peníze." => "ces"
#                                          "Tom koupil několik bochníků chleba." => "ces"

# %%
# import Pkg; Pkg.add(["LanguageFinder", "LanguageDetect", "Languages"])

# %%
# import LanguageFinder: LanguageFind
# detector_lf(t) = LanguageFind(t, 0).lang
import LanguageDetect: detect
detector_ld(t) = first(detect(t)).language
import Languages: LanguageDetector, isocode
Languages_detector = LanguageDetector()
function detector_ls(t)
    l = Languages_detector(t) |> first
    if l == nothing
        return ""
    else
        return l |> isocode
    end
end
using Logging
Logging.disable_logging(Logging.Info)
# Out:
# LogLevel(1)

# %%
include("detector.jl")
detector_lh
# Out:
# WARNING: redefinition of constant TLANGS. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant WLANGS. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant LANGS. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant WLANGMAP. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant TLANGMAP. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant REV_WLANGMAP. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant REV_TLANGMAP. This may fail, cause incorrect answers, or produce other errors.
# detector_lh (generic function with 1 method)

# %% [markdown]
# ## tatoeba

# %%
TB = benchmark(
"detector_ngram1"=>t->detector_lh(t, ngram=1),
"detector_ngram2"=>t->detector_lh(t, ngram=2),
"detector_ngram3"=>t->detector_lh(t, ngram=3),
"detector_ngram4"=>t->detector_lh(t, ngram=4),
"detector_ngram5"=>detector_lh,
# "Languages.jl"=>detector_ls, 
# "LanguageDetect.jl"=>detector_ld,
 dataset=TV, languages=LANGS)
# Out:
# detector_ngram1
#  27.832217 seconds (40.47 M allocations: 3.161 GiB, 1.11% gc time, 0.87% compilation time)
# detector_ngram2
#  85.357987 seconds (63.23 M allocations: 5.854 GiB, 0.68% gc time, 0.07% compilation time)
# detector_ngram3
# 169.830542 seconds (85.08 M allocations: 8.258 GiB, 0.52% gc time, 0.05% compilation time)
# detector_ngram4228.130680 seconds (106.08 M allocations: 10.882 GiB, 0.49% gc time, 0.03% compilation time)
# detector_ngram5286.149266 seconds (126.62 M allocations: 14.058 GiB, 0.39% gc time, 0.03% compilation time)
# 5-element Vector{Any}:
#  "detector_ngram1" => [0.9919327731092437, 0.9412628487518355, 1.0, 0.6808681672025724, 0.49278846153846156, 0.6936193619361937, 0.539333562349708, 0.638541833948932, 1.0, 0.7963418923672178  …  0.3635266307901222, 0.8204697986577181, 0.732778198334595, 0.8821879382889201, 0.7994652406417112, 0.8562215791649442, 0.8105961705831157, 0.9957841483979764, 0.9632183908045977, 1.0]
#  "detector_ngram2" => [0.9899159663865547, 0.9515418502202643, 1.0, 0.7596463022508039, 0.8004807692307693, 0.8567106710671067, 0.7159051872208863, 0.9144692468283282, 1.0, 0.947260816039395  …  0.7640698083790173, 0.9421140939597316, 0.8705526116578349, 0.8990182328190743, 0.9449197860962567, 0.9533416012126223, 0.8052654482158399, 0.9974704890387859, 0.9850574712643678, 1.0]
#  "detector_ngram3" => [0.9912605042016807, 0.9662261380323054, 1.0, 0.8094855305466238, 0.9086538461538461, 0.9106160616061606, 0.7938852627962899, 0.9741769712542155, 1.0, 0.9808960604994724  …  0.9015239149021778, 0.9739932885906041, 0.9318697956093869, 0.9130434782608695, 0.979144385026738, 0.9818657847595426, 0.8651000870322019, 0.9991568296795953, 0.9908045977011494, 1.0]
#  "detector_ngram4" => [0.9919327731092437, 0.9676945668135095, 1.0, 0.8488745980707395, 0.9230769230769231, 0.9243674367436744, 0.8313294400549639, 0.9876344949413843, 1.0, 0.9882826239887443  …  0.9281798521349897, 0.985738255033557, 0.9481453444360333, 0.9186535764375876, 0.9885026737967915, 0.9850902576822378, 0.8945822454308094, 0.9991568296795953, 0.993103448275862, 1.0]
#  "detector_ngram5" => [0.9899159663865547, 0.9691629955947136, 1.0, 0.8633440514469454, 0.9254807692307693, 0.9273927392739274, 0.8505668155273102, 0.9892404046892564, 1.0, 0.989678596552937  …  0.9282301463561837, 0.9865771812080537, 0.9507948523845572, 0.9200561009817672, 0.9911764705882353, 0.9853382940609067, 0.90970409051349, 0.9991568296795953, 0.993103448275862, 1.0]

# %%
showtable(TB, LANGS)
# Out:
# |                 | Average | ara    | bel    | ben     | bul    | cat    | ces    | dan    | deu    | ell     | eng    | epo    | fas    | fin    | fra    | hau    | hbs    | heb    | hin    | hun    | ido    | ina    | isl    | ita    | jpn    | kab    | kor     | kur    | lat    | lit    | mar    | mkd    | msa    | nds    | nld    | nor    | pol    | por    | ron    | rus    | slk    | spa    | swa    | swe    | tat    | tgl    | tur    | ukr    | vie    | yid    | zho     |
# |-----------------|---------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|
# | detector_ngram1 |  74.92% | 99.19% | 94.13% | 100.00% | 68.09% | 49.28% | 69.36% | 53.93% | 63.85% | 100.00% | 79.63% | 71.38% | 97.50% | 83.54% | 43.15% | 60.40% | 10.48% | 97.97% | 83.20% | 87.70% | 33.58% | 11.20% | 88.84% | 35.53% | 99.87% | 87.66% | 100.00% | 98.24% | 87.09% | 90.19% | 80.59% | 74.31% | 69.24% | 42.79% | 65.79% | 42.99% | 94.88% | 61.64% | 83.74% | 85.56% | 76.80% | 36.35% | 82.05% | 73.28% | 88.22% | 79.95% | 85.62% | 81.06% | 99.58% | 96.32% | 100.00% |
# | detector_ngram2 |  88.91% | 98.99% | 95.15% | 100.00% | 75.96% | 80.05% | 85.67% | 71.59% | 91.45% | 100.00% | 94.73% | 88.39% | 98.09% | 97.06% | 87.36% | 94.87% | 11.86% | 97.92% | 86.22% | 96.76% | 76.92% | 70.77% | 96.83% | 85.48% | 99.95% | 97.70% | 100.00% | 98.88% | 93.99% | 97.49% | 84.28% | 83.66% | 92.19% | 81.19% | 91.89% | 72.31% | 98.40% | 89.91% | 90.65% | 87.68% | 86.86% | 76.41% | 94.21% | 87.06% | 89.90% | 94.49% | 95.33% | 80.53% | 99.75% | 98.51% | 100.00% |
# | detector_ngram3 |  93.21% | 99.13% | 96.62% | 100.00% | 80.95% | 90.87% | 91.06% | 79.39% | 97.42% | 100.00% | 98.09% | 96.09% | 98.75% | 98.65% | 95.83% | 98.08% | 16.46% | 98.68% | 86.61% | 98.36% | 88.74% | 90.26% | 98.94% | 95.78% | 99.95% | 99.18% | 100.00% | 99.04% | 95.91% | 98.95% | 84.74% | 90.50% | 96.72% | 94.50% | 96.23% | 84.01% | 99.03% | 96.09% | 95.17% | 91.08% | 90.86% | 90.15% | 97.40% | 93.19% | 91.30% | 97.91% | 98.19% | 86.51% | 99.92% | 99.08% | 100.00% |
# | detector_ngram4 |  94.44% | 99.19% | 96.77% | 100.00% | 84.89% | 92.31% | 92.44% | 83.13% | 98.76% | 100.00% | 98.83% | 97.77% | 99.19% | 98.92% | 97.37% | 98.81% | 22.06% | 99.05% | 89.24% | 98.85% | 91.37% | 95.16% | 99.55% | 97.19% | 99.96% | 99.30% | 100.00% | 99.20% | 95.14% | 99.14% | 87.34% | 94.06% | 97.69% | 96.15% | 97.20% | 85.52% | 99.13% | 97.35% | 96.36% | 92.82% | 90.74% | 92.82% | 98.57% | 94.81% | 91.87% | 98.85% | 98.51% | 89.46% | 99.92% | 99.31% | 100.00% |
# | detector_ngram5 |  94.83% | 98.99% | 96.92% | 100.00% | 86.33% | 92.55% | 92.74% | 85.06% | 98.92% | 100.00% | 98.97% | 97.98% | 99.19% | 98.92% | 97.59% | 99.18% | 25.10% | 99.25% | 93.31% | 98.89% | 91.37% | 95.37% | 99.55% | 96.99% | 99.96% | 99.25% | 100.00% | 99.20% | 94.85% | 99.16% | 89.93% | 96.03% | 97.88% | 96.92% | 97.33% | 84.36% | 99.11% | 97.42% | 96.42% | 93.55% | 90.63% | 92.82% | 98.66% | 95.08% | 92.01% | 99.12% | 98.53% | 90.97% | 99.92% | 99.31% | 100.00% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x31, 0x30, 0x30, 0x2e, 0x30, 0x30, 0x25, 0x20, 0x7c, 0x0a])

# %%
showtable(TB, LANGS, threshold=0.)
# Out:
# 50 columns in total, 50 columns left.
# |                 | Average | ara    | bel    | ben     | bul    | cat    | ces    | dan    | deu    | ell     | eng    | epo    | fas    | fin    | fra    | hau    | hbs    | heb    | hin    | hun    | ido    | ina    | isl    | ita    | jpn    | kab    | kor     | kur    | lat    | lit    | mar    | mkd    | msa    | nds    | nld    | nor    | pol    | por    | ron    | rus    | slk    | spa    | swa    | swe    | tat    | tgl    | tur    | ukr    | vie    | yid    | zho     |
# |-----------------|---------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|
# | detector_ngram1 |  74.92% | 99.19% | 94.13% | 100.00% | 68.09% | 49.28% | 69.36% | 53.93% | 63.85% | 100.00% | 79.63% | 71.38% | 97.50% | 83.54% | 43.15% | 60.40% | 10.48% | 97.97% | 83.20% | 87.70% | 33.58% | 11.20% | 88.84% | 35.53% | 99.87% | 87.66% | 100.00% | 98.24% | 87.09% | 90.19% | 80.59% | 74.31% | 69.24% | 42.79% | 65.79% | 42.99% | 94.88% | 61.64% | 83.74% | 85.56% | 76.80% | 36.35% | 82.05% | 73.28% | 88.22% | 79.95% | 85.62% | 81.06% | 99.58% | 96.32% | 100.00% |
# | detector_ngram2 |  88.91% | 98.99% | 95.15% | 100.00% | 75.96% | 80.05% | 85.67% | 71.59% | 91.45% | 100.00% | 94.73% | 88.39% | 98.09% | 97.06% | 87.36% | 94.87% | 11.86% | 97.92% | 86.22% | 96.76% | 76.92% | 70.77% | 96.83% | 85.48% | 99.95% | 97.70% | 100.00% | 98.88% | 93.99% | 97.49% | 84.28% | 83.66% | 92.19% | 81.19% | 91.89% | 72.31% | 98.40% | 89.91% | 90.65% | 87.68% | 86.86% | 76.41% | 94.21% | 87.06% | 89.90% | 94.49% | 95.33% | 80.53% | 99.75% | 98.51% | 100.00% |
# | detector_ngram3 |  93.21% | 99.13% | 96.62% | 100.00% | 80.95% | 90.87% | 91.06% | 79.39% | 97.42% | 100.00% | 98.09% | 96.09% | 98.75% | 98.65% | 95.83% | 98.08% | 16.46% | 98.68% | 86.61% | 98.36% | 88.74% | 90.26% | 98.94% | 95.78% | 99.95% | 99.18% | 100.00% | 99.04% | 95.91% | 98.95% | 84.74% | 90.50% | 96.72% | 94.50% | 96.23% | 84.01% | 99.03% | 96.09% | 95.17% | 91.08% | 90.86% | 90.15% | 97.40% | 93.19% | 91.30% | 97.91% | 98.19% | 86.51% | 99.92% | 99.08% | 100.00% |
# | detector_ngram4 |  94.44% | 99.19% | 96.77% | 100.00% | 84.89% | 92.31% | 92.44% | 83.13% | 98.76% | 100.00% | 98.83% | 97.77% | 99.19% | 98.92% | 97.37% | 98.81% | 22.06% | 99.05% | 89.24% | 98.85% | 91.37% | 95.16% | 99.55% | 97.19% | 99.96% | 99.30% | 100.00% | 99.20% | 95.14% | 99.14% | 87.34% | 94.06% | 97.69% | 96.15% | 97.20% | 85.52% | 99.13% | 97.35% | 96.36% | 92.82% | 90.74% | 92.82% | 98.57% | 94.81% | 91.87% | 98.85% | 98.51% | 89.46% | 99.92% | 99.31% | 100.00% |
# | detector_ngram5 |  94.83% | 98.99% | 96.92% | 100.00% | 86.33% | 92.55% | 92.74% | 85.06% | 98.92% | 100.00% | 98.97% | 97.98% | 99.19% | 98.92% | 97.59% | 99.18% | 25.10% | 99.25% | 93.31% | 98.89% | 91.37% | 95.37% | 99.55% | 96.99% | 99.96% | 99.25% | 100.00% | 99.20% | 94.85% | 99.16% | 89.93% | 96.03% | 97.88% | 96.92% | 97.33% | 84.36% | 99.11% | 97.42% | 96.42% | 93.55% | 90.63% | 92.82% | 98.66% | 95.08% | 92.01% | 99.12% | 98.53% | 90.97% | 99.92% | 99.31% | 100.00% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x31, 0x30, 0x30, 0x2e, 0x30, 0x30, 0x25, 0x20, 0x7c, 0x0a])

# %%
showtable(TB, LANGS, threshold=0.5)
# Out:
# 50 columns in total, 41 columns left.
# |                 | Average | ara    | bel    | ben     | bul    | ces    | dan    | deu    | ell     | eng    | epo    | fas    | fin    | hau    | heb    | hin    | hun    | isl    | jpn    | kab    | kor     | kur    | lat    | lit    | mar    | mkd    | msa    | nld    | pol    | por    | ron    | rus    | slk    | swa    | swe    | tat    | tgl    | tur    | ukr    | vie    | yid    | zho     |
# |-----------------|---------|--------|--------|---------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|
# | detector_ngram1 |  83.91% | 99.19% | 94.13% | 100.00% | 68.09% | 69.36% | 53.93% | 63.85% | 100.00% | 79.63% | 71.38% | 97.50% | 83.54% | 60.40% | 97.97% | 83.20% | 87.70% | 88.84% | 99.87% | 87.66% | 100.00% | 98.24% | 87.09% | 90.19% | 80.59% | 74.31% | 69.24% | 65.79% | 94.88% | 61.64% | 83.74% | 85.56% | 76.80% | 82.05% | 73.28% | 88.22% | 79.95% | 85.62% | 81.06% | 99.58% | 96.32% | 100.00% |
# | detector_ngram2 |  92.76% | 98.99% | 95.15% | 100.00% | 75.96% | 85.67% | 71.59% | 91.45% | 100.00% | 94.73% | 88.39% | 98.09% | 97.06% | 94.87% | 97.92% | 86.22% | 96.76% | 96.83% | 99.95% | 97.70% | 100.00% | 98.88% | 93.99% | 97.49% | 84.28% | 83.66% | 92.19% | 91.89% | 98.40% | 89.91% | 90.65% | 87.68% | 86.86% | 94.21% | 87.06% | 89.90% | 94.49% | 95.33% | 80.53% | 99.75% | 98.51% | 100.00% |
# | detector_ngram3 |  95.46% | 99.13% | 96.62% | 100.00% | 80.95% | 91.06% | 79.39% | 97.42% | 100.00% | 98.09% | 96.09% | 98.75% | 98.65% | 98.08% | 98.68% | 86.61% | 98.36% | 98.94% | 99.95% | 99.18% | 100.00% | 99.04% | 95.91% | 98.95% | 84.74% | 90.50% | 96.72% | 96.23% | 99.03% | 96.09% | 95.17% | 91.08% | 90.86% | 97.40% | 93.19% | 91.30% | 97.91% | 98.19% | 86.51% | 99.92% | 99.08% | 100.00% |
# | detector_ngram4 |  96.39% | 99.19% | 96.77% | 100.00% | 84.89% | 92.44% | 83.13% | 98.76% | 100.00% | 98.83% | 97.77% | 99.19% | 98.92% | 98.81% | 99.05% | 89.24% | 98.85% | 99.55% | 99.96% | 99.30% | 100.00% | 99.20% | 95.14% | 99.14% | 87.34% | 94.06% | 97.69% | 97.20% | 99.13% | 97.35% | 96.36% | 92.82% | 90.74% | 98.57% | 94.81% | 91.87% | 98.85% | 98.51% | 89.46% | 99.92% | 99.31% | 100.00% |
# | detector_ngram5 |  96.79% | 98.99% | 96.92% | 100.00% | 86.33% | 92.74% | 85.06% | 98.92% | 100.00% | 98.97% | 97.98% | 99.19% | 98.92% | 99.18% | 99.25% | 93.31% | 98.89% | 99.55% | 99.96% | 99.25% | 100.00% | 99.20% | 94.85% | 99.16% | 89.93% | 96.03% | 97.88% | 97.33% | 99.11% | 97.42% | 96.42% | 93.55% | 90.63% | 98.66% | 95.08% | 92.01% | 99.12% | 98.53% | 90.97% | 99.92% | 99.31% | 100.00% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x31, 0x30, 0x30, 0x2e, 0x30, 0x30, 0x25, 0x20, 0x7c, 0x0a])

# %% [markdown]
# ## wikipedia

# %%
WB = benchmark(
"detector_ngram1"=>t->detector_lh(t, ngram=1),
"detector_ngram2"=>t->detector_lh(t, ngram=2),
"detector_ngram3"=>t->detector_lh(t, ngram=3),
"detector_ngram4"=>t->detector_lh(t, ngram=4),
"detector_ngram5"=>detector_lh,
# "Languages.jl"=>detector_ls, 
# "LanguageDetect.jl"=>detector_ld,
 dataset=WV, languages=LANGS)
# Out:
# detector_ngram1 60.019037 seconds (18.98 M allocations: 1.299 GiB, 0.28% gc time, 0.15% compilation time)
# detector_ngram2 14.281260 seconds (37.25 M allocations: 2.512 GiB, 2.02% gc time, 0.43% compilation time)
# detector_ngram3
#  30.437842 seconds (55.49 M allocations: 3.933 GiB, 1.43% gc time, 0.20% compilation time)
# detector_ngram4 53.013963 seconds (73.71 M allocations: 5.453 GiB, 1.10% gc time, 0.13% compilation time)
# detector_ngram5 82.294516 seconds (91.91 M allocations: 7.130 GiB, 0.90% gc time, 0.07% compilation time)
# 5-element Vector{Any}:
#  "detector_ngram1" => [0.995, 0.99, 1.0, 0.89, 0.985, 0.945, 0.86, 0.94, 1.0, 0.895  …  0.965, 0.955, 0.955, 0.985, 0.88, 0.985, 0.975, 0.97, 0.955, 1.0]
#  "detector_ngram2" => [0.995, 0.99, 1.0, 0.94, 0.995, 0.965, 0.97, 0.955, 1.0, 0.995  …  0.995, 0.985, 0.985, 0.985, 0.975, 0.99, 0.985, 0.965, 0.975, 1.0]
#  "detector_ngram3" => [0.995, 0.99, 1.0, 0.975, 1.0, 0.97, 0.965, 0.955, 1.0, 1.0  …  1.0, 0.995, 0.985, 0.99, 0.985, 0.99, 1.0, 0.965, 0.98, 1.0]
#  "detector_ngram4" => [1.0, 0.995, 1.0, 0.99, 1.0, 0.975, 0.98, 0.965, 1.0, 1.0  …  1.0, 0.995, 0.985, 0.99, 0.985, 0.99, 1.0, 0.965, 0.985, 0.995]
#  "detector_ngram5" => [1.0, 1.0, 1.0, 0.995, 1.0, 0.975, 0.985, 0.965, 1.0, 1.0  …  1.0, 0.995, 0.99, 0.99, 0.985, 0.99, 1.0, 0.965, 0.985, 0.995]

# %%
showtable(WB, LANGS)
# Out:
# |                 | Average | ara     | bel     | ben     | bul    | cat     | ces    | dan    | deu    | ell     | eng     | epo     | fas     | fin    | fra     | hau    | hbs    | heb     | hin    | hun    | ido    | ina    | isl    | ita     | jpn    | kab    | kor    | kur    | lat    | lit     | mar    | mkd     | msa    | nds    | nld    | nor    | pol     | por    | ron    | rus     | slk    | spa     | swa    | swe    | tat    | tgl    | tur    | ukr     | vie    | yid    | zho     |
# |-----------------|---------|---------|---------|---------|--------|---------|--------|--------|--------|---------|---------|---------|---------|--------|---------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|---------|--------|--------|--------|--------|---------|--------|--------|---------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|---------|
# | detector_ngram1 |  88.98% |  99.50% |  99.00% | 100.00% | 89.00% |  98.50% | 94.50% | 86.00% | 94.00% | 100.00% |  89.50% |  91.00% |  99.50% | 94.50% |  78.50% | 84.00% | 11.00% | 100.00% | 90.00% | 99.00% | 67.50% |  5.00% | 94.00% |  79.50% | 93.00% | 94.00% | 98.50% | 99.00% | 95.50% |  98.50% | 91.00% |  91.00% | 91.50% | 84.50% | 77.50% | 54.00% |  98.50% | 93.00% | 88.00% |  99.00% | 96.50% |  96.50% | 95.50% | 95.50% | 98.50% | 88.00% | 98.50% |  97.50% | 97.00% | 95.50% | 100.00% |
# | detector_ngram2 |  94.93% |  99.50% |  99.00% | 100.00% | 94.00% |  99.50% | 96.50% | 97.00% | 95.50% | 100.00% |  99.50% |  96.00% |  99.50% | 99.00% |  99.00% | 95.50% | 21.00% | 100.00% | 89.50% | 99.50% | 84.50% | 75.00% | 98.00% |  96.00% | 94.50% | 97.00% | 98.00% | 99.00% | 96.00% | 100.00% | 91.50% |  94.00% | 98.50% | 98.00% | 95.00% | 88.50% |  99.50% | 97.00% | 87.00% |  99.00% | 97.00% |  99.50% | 98.50% | 98.50% | 98.50% | 97.50% | 99.00% |  98.50% | 96.50% | 97.50% | 100.00% |
# | detector_ngram3 |  97.14% |  99.50% |  99.00% | 100.00% | 97.50% | 100.00% | 97.00% | 96.50% | 95.50% | 100.00% | 100.00% |  99.50% | 100.00% | 99.00% | 100.00% | 99.00% | 63.50% | 100.00% | 89.50% | 99.00% | 92.50% | 88.50% | 98.50% |  99.00% | 97.50% | 99.00% | 97.00% | 99.00% | 98.50% | 100.00% | 91.50% |  97.00% | 99.00% | 99.00% | 96.00% | 96.00% |  99.50% | 99.50% | 90.00% |  99.50% | 97.00% | 100.00% | 99.50% | 98.50% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 98.00% | 100.00% |
# | detector_ngram4 |  97.95% | 100.00% |  99.50% | 100.00% | 99.00% | 100.00% | 97.50% | 98.00% | 96.50% | 100.00% | 100.00% | 100.00% | 100.00% | 99.00% | 100.00% | 99.50% | 83.50% | 100.00% | 90.00% | 99.00% | 93.50% | 92.00% | 98.50% | 100.00% | 98.00% | 99.00% | 97.50% | 99.00% | 98.00% | 100.00% | 94.00% |  99.00% | 99.50% | 99.00% | 97.00% | 97.00% | 100.00% | 99.50% | 90.00% |  99.50% | 97.00% | 100.00% | 99.50% | 98.50% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 98.50% |  99.50% |
# | detector_ngram5 |  98.41% | 100.00% | 100.00% | 100.00% | 99.50% | 100.00% | 97.50% | 98.50% | 96.50% | 100.00% | 100.00% | 100.00% | 100.00% | 99.00% | 100.00% | 99.50% | 89.50% | 100.00% | 94.00% | 99.50% | 95.00% | 96.00% | 98.50% | 100.00% | 98.00% | 99.00% | 97.00% | 99.00% | 98.50% | 100.00% | 96.50% | 100.00% | 99.50% | 99.50% | 97.50% | 96.50% | 100.00% | 99.50% | 90.50% | 100.00% | 97.00% | 100.00% | 99.50% | 99.00% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 98.50% |  99.50% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x20, 0x39, 0x39, 0x2e, 0x35, 0x30, 0x25, 0x20, 0x7c, 0x0a])

# %%
showtable(WB, LANGS, threshold=0.)
# Out:
# 50 columns in total, 50 columns left.
# |                 | Average | ara     | bel     | ben     | bul    | cat     | ces    | dan    | deu    | ell     | eng     | epo     | fas     | fin    | fra     | hau    | hbs    | heb     | hin    | hun    | ido    | ina    | isl    | ita     | jpn    | kab    | kor    | kur    | lat    | lit     | mar    | mkd     | msa    | nds    | nld    | nor    | pol     | por    | ron    | rus     | slk    | spa     | swa    | swe    | tat    | tgl    | tur    | ukr     | vie    | yid    | zho     |
# |-----------------|---------|---------|---------|---------|--------|---------|--------|--------|--------|---------|---------|---------|---------|--------|---------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|---------|--------|--------|--------|--------|---------|--------|--------|---------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|---------|
# | detector_ngram1 |  88.98% |  99.50% |  99.00% | 100.00% | 89.00% |  98.50% | 94.50% | 86.00% | 94.00% | 100.00% |  89.50% |  91.00% |  99.50% | 94.50% |  78.50% | 84.00% | 11.00% | 100.00% | 90.00% | 99.00% | 67.50% |  5.00% | 94.00% |  79.50% | 93.00% | 94.00% | 98.50% | 99.00% | 95.50% |  98.50% | 91.00% |  91.00% | 91.50% | 84.50% | 77.50% | 54.00% |  98.50% | 93.00% | 88.00% |  99.00% | 96.50% |  96.50% | 95.50% | 95.50% | 98.50% | 88.00% | 98.50% |  97.50% | 97.00% | 95.50% | 100.00% |
# | detector_ngram2 |  94.93% |  99.50% |  99.00% | 100.00% | 94.00% |  99.50% | 96.50% | 97.00% | 95.50% | 100.00% |  99.50% |  96.00% |  99.50% | 99.00% |  99.00% | 95.50% | 21.00% | 100.00% | 89.50% | 99.50% | 84.50% | 75.00% | 98.00% |  96.00% | 94.50% | 97.00% | 98.00% | 99.00% | 96.00% | 100.00% | 91.50% |  94.00% | 98.50% | 98.00% | 95.00% | 88.50% |  99.50% | 97.00% | 87.00% |  99.00% | 97.00% |  99.50% | 98.50% | 98.50% | 98.50% | 97.50% | 99.00% |  98.50% | 96.50% | 97.50% | 100.00% |
# | detector_ngram3 |  97.14% |  99.50% |  99.00% | 100.00% | 97.50% | 100.00% | 97.00% | 96.50% | 95.50% | 100.00% | 100.00% |  99.50% | 100.00% | 99.00% | 100.00% | 99.00% | 63.50% | 100.00% | 89.50% | 99.00% | 92.50% | 88.50% | 98.50% |  99.00% | 97.50% | 99.00% | 97.00% | 99.00% | 98.50% | 100.00% | 91.50% |  97.00% | 99.00% | 99.00% | 96.00% | 96.00% |  99.50% | 99.50% | 90.00% |  99.50% | 97.00% | 100.00% | 99.50% | 98.50% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 98.00% | 100.00% |
# | detector_ngram4 |  97.95% | 100.00% |  99.50% | 100.00% | 99.00% | 100.00% | 97.50% | 98.00% | 96.50% | 100.00% | 100.00% | 100.00% | 100.00% | 99.00% | 100.00% | 99.50% | 83.50% | 100.00% | 90.00% | 99.00% | 93.50% | 92.00% | 98.50% | 100.00% | 98.00% | 99.00% | 97.50% | 99.00% | 98.00% | 100.00% | 94.00% |  99.00% | 99.50% | 99.00% | 97.00% | 97.00% | 100.00% | 99.50% | 90.00% |  99.50% | 97.00% | 100.00% | 99.50% | 98.50% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 98.50% |  99.50% |
# | detector_ngram5 |  98.41% | 100.00% | 100.00% | 100.00% | 99.50% | 100.00% | 97.50% | 98.50% | 96.50% | 100.00% | 100.00% | 100.00% | 100.00% | 99.00% | 100.00% | 99.50% | 89.50% | 100.00% | 94.00% | 99.50% | 95.00% | 96.00% | 98.50% | 100.00% | 98.00% | 99.00% | 97.00% | 99.00% | 98.50% | 100.00% | 96.50% | 100.00% | 99.50% | 99.50% | 97.50% | 96.50% | 100.00% | 99.50% | 90.50% | 100.00% | 97.00% | 100.00% | 99.50% | 99.00% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 98.50% |  99.50% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x20, 0x39, 0x39, 0x2e, 0x35, 0x30, 0x25, 0x20, 0x7c, 0x0a])

# %%
showtable(WB, LANGS, threshold=0.5)
# Out:
# 50 columns in total, 48 columns left.
# |                 | Average | ara     | bel     | ben     | bul    | cat     | ces    | dan    | deu    | ell     | eng     | epo     | fas     | fin    | fra     | hau    | heb     | hin    | hun    | ido    | isl    | ita     | jpn    | kab    | kor    | kur    | lat    | lit     | mar    | mkd     | msa    | nds    | nld    | nor    | pol     | por    | ron    | rus     | slk    | spa     | swa    | swe    | tat    | tgl    | tur    | ukr     | vie    | yid    | zho     |
# |-----------------|---------|---------|---------|---------|--------|---------|--------|--------|--------|---------|---------|---------|---------|--------|---------|--------|---------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|---------|--------|--------|--------|--------|---------|--------|--------|---------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|---------|
# | detector_ngram1 |  92.35% |  99.50% |  99.00% | 100.00% | 89.00% |  98.50% | 94.50% | 86.00% | 94.00% | 100.00% |  89.50% |  91.00% |  99.50% | 94.50% |  78.50% | 84.00% | 100.00% | 90.00% | 99.00% | 67.50% | 94.00% |  79.50% | 93.00% | 94.00% | 98.50% | 99.00% | 95.50% |  98.50% | 91.00% |  91.00% | 91.50% | 84.50% | 77.50% | 54.00% |  98.50% | 93.00% | 88.00% |  99.00% | 96.50% |  96.50% | 95.50% | 95.50% | 98.50% | 88.00% | 98.50% |  97.50% | 97.00% | 95.50% | 100.00% |
# | detector_ngram2 |  96.89% |  99.50% |  99.00% | 100.00% | 94.00% |  99.50% | 96.50% | 97.00% | 95.50% | 100.00% |  99.50% |  96.00% |  99.50% | 99.00% |  99.00% | 95.50% | 100.00% | 89.50% | 99.50% | 84.50% | 98.00% |  96.00% | 94.50% | 97.00% | 98.00% | 99.00% | 96.00% | 100.00% | 91.50% |  94.00% | 98.50% | 98.00% | 95.00% | 88.50% |  99.50% | 97.00% | 87.00% |  99.00% | 97.00% |  99.50% | 98.50% | 98.50% | 98.50% | 97.50% | 99.00% |  98.50% | 96.50% | 97.50% | 100.00% |
# | detector_ngram3 |  98.02% |  99.50% |  99.00% | 100.00% | 97.50% | 100.00% | 97.00% | 96.50% | 95.50% | 100.00% | 100.00% |  99.50% | 100.00% | 99.00% | 100.00% | 99.00% | 100.00% | 89.50% | 99.00% | 92.50% | 98.50% |  99.00% | 97.50% | 99.00% | 97.00% | 99.00% | 98.50% | 100.00% | 91.50% |  97.00% | 99.00% | 99.00% | 96.00% | 96.00% |  99.50% | 99.50% | 90.00% |  99.50% | 97.00% | 100.00% | 99.50% | 98.50% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 98.00% | 100.00% |
# | detector_ngram4 |  98.37% | 100.00% |  99.50% | 100.00% | 99.00% | 100.00% | 97.50% | 98.00% | 96.50% | 100.00% | 100.00% | 100.00% | 100.00% | 99.00% | 100.00% | 99.50% | 100.00% | 90.00% | 99.00% | 93.50% | 98.50% | 100.00% | 98.00% | 99.00% | 97.50% | 99.00% | 98.00% | 100.00% | 94.00% |  99.00% | 99.50% | 99.00% | 97.00% | 97.00% | 100.00% | 99.50% | 90.00% |  99.50% | 97.00% | 100.00% | 99.50% | 98.50% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 98.50% |  99.50% |
# | detector_ngram5 |  98.65% | 100.00% | 100.00% | 100.00% | 99.50% | 100.00% | 97.50% | 98.50% | 96.50% | 100.00% | 100.00% | 100.00% | 100.00% | 99.00% | 100.00% | 99.50% | 100.00% | 94.00% | 99.50% | 95.00% | 98.50% | 100.00% | 98.00% | 99.00% | 97.00% | 99.00% | 98.50% | 100.00% | 96.50% | 100.00% | 99.50% | 99.50% | 97.50% | 96.50% | 100.00% | 99.50% | 90.50% | 100.00% | 97.00% | 100.00% | 99.50% | 99.00% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 98.50% |  99.50% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x20, 0x39, 0x39, 0x2e, 0x35, 0x30, 0x25, 0x20, 0x7c, 0x0a])

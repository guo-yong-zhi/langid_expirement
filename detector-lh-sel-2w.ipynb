# %%
using Revise
include("ngrams.jl")
include("datasetloader.jl")
LANGS = ["ara", "bel", "ben", "bul", "cat", "ces", "dan", "deu", "ell", 
"eng", "epo", "fas", "fin", "fra", "hau", "hbs", "heb", "hin", "hun", 
"ido", "ina", "isl", "ita", "jpn", "kab", "kor", "kur", "lat", "lit", 
"mar", "mkd", "msa", "nds", "nld", "nor", "pol", "por", "ron", "rus", 
"slk", "spa", "swa", "swe", "tat", "tgl", "tur", "ukr", "vie", "yid", 
"zho"]
G = [lang => load_ngrams(joinpath("ngrams", lang * ".txt")) for lang in LANGS]
# Out:
# 50-element Vector{Pair{String, Dict{Tuple{UInt8, Vararg{UInt8}}, Float64}}}:
#  "ara" => Dict((0x63, 0x61) => 0.00029467622074500394, (0x68, 0x65) => 0.00010555566116238947, (0x63, 0x20, 0x6d) => 0.00010555566116238947, (0xd8, 0xb4, 0xd8) => 0.01657449209142566, (0x70, 0x75, 0x74) => 0.004037504039461398, (0xa8, 0xd8) => 0.05337699287247487, (0xaf,) => 0.08298881434086272, (0xd9, 0x87, 0xd8) => 0.030677597244273158, (0xb3, 0x20) => 0.010194608449073564, (0x74, 0x20, 0x65, 0x6e) => 0.003931948378299008…)
#  "bel" => Dict((0xd0, 0xb0, 0x20, 0xd0) => 0.05356847819684612, (0x80, 0xd0, 0xbd, 0xd1) => 0.0017948414065424912, (0xb0, 0x20, 0xd1, 0x82, 0xd1) => 0.0016050908823657271, (0xb0, 0xd0, 0xbc, 0xd0, 0xbe) => 0.0012221484089284342, (0xbb, 0xd0, 0xba, 0xd0) => 0.000577329909094111, (0xd0, 0xbd, 0xd1, 0x83) => 0.005204917113475131, (0xb3, 0xd0, 0xb5, 0xd0, 0xbd) => 0.0005244402681460933, (0xd1, 0x87) => 0.03788978898882851, (0xd0, 0xb3, 0xd0, 0xbb) => 0.0028589731977762345, (0x63, 0x61) => 9.886008612132829e-5…)
#  "ben" => Dict((0xa3,) => 0.012157689940466211, (0xb9, 0x20, 0xe0) => 0.016853856991339254, (0x63, 0x61) => 5.498135387647386e-5, (0x68, 0x65) => 0.00015736042661197692, (0x20, 0x72, 0x65, 0x66) => 6.066908013955736e-5, (0x20, 0x6e) => 8.72118027006137e-5, (0x68, 0x20) => 5.87731713851962e-5, (0x70, 0x75, 0x74) => 6.256498889391853e-5, (0x20, 0x62) => 0.00015112696412113415, (0x20, 0x63, 0x6f) => 9.669134647241955e-5…)
#  "bul" => Dict((0xd1, 0x87) => 0.038097761413004666, (0xd0, 0xb3, 0xd0, 0xbb) => 0.003440523530680391, (0x68, 0x65) => 0.00018840507815672555, (0xbe, 0x20, 0xd0, 0xba) => 0.0030232829231910466, (0xd0, 0xb8, 0xd0, 0xb5) => 0.007641657592596681, (0xb8, 0xd0, 0xbc) => 0.009666047595330976, (0x20, 0xd0, 0xb3, 0xd0, 0xb5) => 0.0011576698045249589, (0xb3, 0x20) => 0.004569980778722145, (0x70, 0x72) => 7.561377721401971e-5, (0x6f, 0x6c) => 7.561377721401971e-5…)
#  "cat" => Dict((0x63, 0x61, 0x76) => 0.00040399570539781664, (0x75, 0x72, 0x61, 0x72) => 0.00039228610564043525, (0x65, 0x63, 0x68) => 0.0001954636569956965, (0x65, 0x20, 0x73, 0x65, 0x6d) => 0.00015197591963007705, (0x6f, 0x72, 0x61, 0x6e) => 0.0002509171282186575, (0x68, 0x65) => 0.005559339306013076, (0x65, 0x72, 0x20, 0x74, 0x72) => 0.00032978979895638134, (0x64, 0x69, 0x65, 0x6e) => 0.0002167629194456152, (0x6d, 0x20, 0x67) => 0.0001554973373606235, (0x66, 0x69, 0x63, 0x69, 0x61) => 0.00035091830533966…)
#  "ces" => Dict((0x6c, 0x65, 0x20, 0x6f) => 0.0004066304900774201, (0x64, 0x65, 0x74, 0x65) => 0.00026609031500124077, (0x6f, 0x20, 0x6e) => 0.007254404826304751, (0x74, 0x69, 0x62) => 7.320003162003136e-5, (0x72, 0x65, 0x64, 0x69) => 8.351206264809786e-5, (0x6d, 0x20, 0x6e, 0x61, 0x20) => 0.0011920352007044317, (0x68, 0x61, 0x72, 0x6c) => 9.118076410645867e-5, (0x74, 0x61, 0x20, 0x6b) => 0.00026759023222821686, (0x6b, 0x20, 0x6b) => 0.0007347742893953974, (0xb3, 0x20) => 9.307565791578347e-5…)
#  "dan" => Dict((0x65, 0x72, 0x20, 0x74, 0x72) => 0.0006133164026485304, (0x64, 0x69, 0x65, 0x6e) => 0.00013005924861750763, (0x74, 0x20, 0x62, 0x6c) => 0.0017678765842053803, (0x6c, 0x65, 0x20, 0x6f) => 0.0006485055307919377, (0x74, 0x69, 0x62) => 0.00011929617869649176, (0x72, 0x65, 0x64, 0x69) => 0.0003161076132972695, (0x66, 0x72, 0xc3) => 0.00017471424022514278, (0x6b, 0x20, 0x6b) => 0.0005855227697718972, (0x70, 0x72) => 0.008290696637034327, (0x61, 0x6c, 0x6c, 0x65, 0x72) => 0.0008847690243381648…)
#  "deu" => Dict((0x65, 0x72, 0x20, 0x74, 0x72) => 0.0004501476640740769, (0x74, 0x20, 0x62, 0x6c) => 0.0002022139003218596, (0x6c, 0x65, 0x20, 0x6f) => 6.382967716240672e-5, (0x6f, 0x20, 0x6e) => 0.0002983833172090488, (0x61, 0x6e, 0x64, 0x61, 0x6e) => 1.7822401862197646e-5, (0x6d, 0x65, 0x68) => 0.002181609932690197, (0x61, 0x6c, 0x6c, 0x65, 0x72) => 0.000447387195291985, (0x6f, 0x73, 0x74, 0x65, 0x72) => 0.0001740875816332964, (0x66, 0x61, 0x20) => 9.379304151718921e-5, (0x74, 0x70, 0x75, 0x74) => 0.00016348898876477418…)
#  "ell" => Dict((0x63, 0x61) => 0.00013425768342911943, (0x68, 0x65) => 0.00028752393500937513, (0x20, 0x6f, 0x66, 0x20) => 7.94946809777681e-5, (0x77, 0x69) => 7.553811906866023e-5, (0xaf,) => 0.08188954469906531, (0xb3, 0x20) => 0.00011468449530896637, (0x70, 0x72) => 4.593026012048823e-5, (0x6f, 0x6c) => 0.0001693063427680635, (0x69, 0x6e, 0x75) => 6.182919631604185e-5, (0x74, 0x65, 0x6e) => 5.1229905519006105e-5…)
#  "eng" => Dict((0x63, 0x61, 0x76) => 0.00011067807256312069, (0x65, 0x72, 0x20, 0x74, 0x72) => 0.00011072501188468827, (0x74, 0x20, 0x62, 0x6c) => 0.00010004949202733313, (0x6c, 0x65, 0x20, 0x6f) => 0.0008251626025680369, (0x6f, 0x20, 0x6e) => 0.000882118666553424, (0x63, 0x61, 0x74, 0x61) => 9.913272569522857e-5, (0x6d, 0x65, 0x68) => 2.1168863123746183e-5, (0x61, 0x6c, 0x6c, 0x65, 0x72) => 0.00022946531610454587, (0x6f, 0x73, 0x74, 0x65, 0x72) => 5.868602746016954e-5, (0x66, 0x61, 0x20) => 9.487513296099261e-5…)
#        ⋮
#  "swa" => Dict((0x65, 0x63, 0x68) => 0.0005070205949326161, (0x20, 0x6c, 0x61, 0x75) => 6.792442849383098e-5, (0x68, 0x65) => 0.01419299344753601, (0x6c, 0x69, 0x74, 0x75) => 0.000839858145671297, (0x74, 0x69, 0x62) => 0.0012566620821385247, (0x72, 0x61, 0x74, 0x61, 0x20) => 0.00011201636825952614, (0x6f, 0x20, 0x6e) => 0.01156402226552787, (0x63, 0x69, 0x65) => 8.0733932280543e-5, (0x74, 0x61, 0x20, 0x6a) => 0.00030058588736963, (0x61, 0x6e, 0x64, 0x61, 0x6e) => 0.00013733150396325576…)
#  "swe" => Dict((0x75, 0x72, 0x61, 0x72) => 5.8997615490617414e-5, (0x65, 0x72, 0x20, 0x74, 0x72) => 0.00022387625611585858, (0x64, 0x69, 0x65, 0x6e) => 0.0001213875668726913, (0x74, 0x20, 0x62, 0x6c) => 0.0007293102571570053, (0x73, 0x61, 0x20, 0x64) => 0.00037008079250335255, (0x63, 0x61, 0x74, 0x61) => 0.002806403210219637, (0x72, 0x65, 0x64, 0x69) => 0.0001507739879221116, (0x74, 0x61, 0x20, 0x6b) => 0.0004058881009058821, (0x66, 0x72, 0xc3) => 0.004870571448516835, (0x6b, 0x20, 0x6b) => 0.00034223527152689714…)
#  "tat" => Dict((0xd1, 0x87) => 0.037048206543208874, (0xd0, 0xb3, 0xd0, 0xbb) => 0.0005681826927732175, (0x68, 0x65) => 0.00025420042328287175, (0xbe, 0x20, 0xd0, 0xba) => 0.0003175218894043667, (0xd0, 0xb8, 0xd0, 0xb5) => 0.002539166143850407, (0xb8, 0xd0, 0xbc) => 0.005929307838282421, (0x20, 0xd0, 0xb3, 0xd0, 0xb5) => 0.0020774639638475255, (0xb3, 0x20) => 0.0005013356487180461, (0x6f, 0x6c) => 0.00018263388600900566, (0xbe, 0xd1, 0x82, 0xd0, 0xbe) => 0.00015058220217675772…)
#  "tgl" => Dict((0x63, 0x61, 0x76) => 0.00011414003412287872, (0x67, 0x20, 0x62, 0x61) => 0.01007889329982544, (0x65, 0x63, 0x68) => 0.0001032730540339698, (0x6f, 0x72, 0x61, 0x6e) => 7.694131781369074e-5, (0x68, 0x65) => 0.005623152804279014, (0x6d, 0x20, 0x67) => 5.5502716049827435e-5, (0x6c, 0x69, 0x74, 0x75) => 9.304374750020649e-5, (0x74, 0x69, 0x62) => 0.0009205436745842251, (0x72, 0x61, 0x74, 0x61, 0x20) => 0.0001936721938591208, (0x6f, 0x20, 0x6e) => 0.023963027348983427…)
#  "tur" => Dict((0x63, 0x61, 0x76) => 4.366048974062704e-5, (0x75, 0x72, 0x61, 0x72) => 3.931140890831504e-5, (0x6c, 0x65, 0x20, 0x6f) => 0.0006532778461495405, (0x6f, 0x20, 0x6e) => 0.00032846910805802023, (0x61, 0x6e, 0x64, 0x61, 0x6e) => 0.0004113072166913724, (0x74, 0x61, 0x20, 0x6b) => 0.0003671892855067855, (0x6d, 0x65, 0x68) => 0.0002448852739449923, (0x61, 0x6c, 0x6c, 0x65, 0x72) => 0.0002622611028734094, (0x6f, 0x73, 0x74, 0x65, 0x72) => 2.333391531976339e-5, (0x66, 0x61, 0x20) => 0.0006229935573376693…)
#  "ukr" => Dict((0xd1, 0x87) => 0.03655393379647023, (0xd0, 0xb3, 0xd0, 0xbb) => 0.002111356419584099, (0x68, 0x65) => 0.0001293825254080179, (0xbe, 0x20, 0xd0, 0xba) => 0.0019512529960713865, (0xb8, 0xd0, 0xbc) => 0.00912189622564041, (0x20, 0xd0, 0xb3, 0xd0, 0xb5) => 0.0008504670601970352, (0xb3, 0x20) => 0.0017642425185250945, (0x70, 0x72) => 0.00025671551385375265, (0x6f, 0x6c) => 0.00015480389383556927, (0xbe, 0xd1, 0x82, 0xd0, 0xbe) => 0.0009603711859982635…)
#  "vie" => Dict((0x67, 0x20, 0x62, 0x61) => 0.0007502687289245116, (0x63, 0x61) => 0.0037955070971542517, (0x20, 0x6c, 0x61, 0x75) => 0.0001914298564099633, (0x6e, 0x20, 0x74) => 0.021223854335752655, (0x74, 0x6f, 0x6d, 0x20) => 0.007175726953169854, (0x68, 0x65) => 0.004437868679115533, (0x6d, 0x20, 0x67) => 0.0013662156651672226, (0x63, 0x20, 0x6d) => 0.0025544317538235125, (0x79, 0x6c, 0x61) => 0.00011561261800936569, (0x69, 0x61, 0x20, 0x73) => 0.00021964715213799288…)
#  "yid" => Dict((0x98,) => 0.16326045998269817, (0x66,) => 7.881389041405151e-5, (0xaa,) => 0.011960774014529484, (0xa8, 0xd7) => 0.11767057653973406, (0xd7, 0xa8, 0xd7) => 0.11767057653973406, (0xa3,) => 0.006265805511481912, (0xd7, 0xa2) => 0.25646148111201866, (0x97, 0x20) => 0.0014868134199577062, (0x9e, 0xd7) => 0.06788181205973351, (0x65,) => 0.0004778909261901144…)
#  "zho" => Dict((0x62, 0x6f, 0x6f) => 8.421320762078037e-5, (0x63, 0x61) => 0.0006814056304984358, (0x79, 0x61) => 0.0002526677859584617, (0x6e, 0x63, 0x65) => 0.0004078224763906481, (0x74, 0x6f, 0x6d, 0x20) => 7.24033885086359e-5, (0x68, 0x65) => 0.0007360670878176457, (0x63, 0x20, 0x6d) => 0.00024207216812792962, (0x6e, 0x73, 0x20) => 0.0001831338038018671, (0x6f, 0x20, 0x6e) => 0.0002360293248159883, (0x70, 0x75, 0x74) => 0.001975621243108587…)

# %%
sort([l=>sum(values(D)) for (l,D) in G], by=last, rev=true)
# Out:
# 50-element Vector{Pair{String, Float64}}:
#  "rus" => 30.187791629025785
#  "mkd" => 28.896797026857826
#  "bul" => 27.42843419163413
#  "ukr" => 26.62244988563177
#  "hbs" => 25.980957657438083
#  "ita" => 25.71077834720614
#  "spa" => 25.413867437643315
#  "eng" => 24.86775581839151
#  "fra" => 24.5766081478693
#  "ina" => 24.495512105571148
#        ⋮
#  "heb" => 13.47283958076938
#  "yid" => 12.132529131967047
#  "kur" => 11.971806223760582
#  "vie" => 11.952140372144667
#  "ben" => 9.181655235780324
#  "zho" => 8.158283496795718
#  "jpn" => 7.267760355040137
#  "ell" => 6.931174949876233
#  "kor" => 4.717837692404967

# %%
function norm_table!(t)
    D = last(t)
    vs = sum(values(D))
    for (k, v) in D
        D[k] /= vs
        D[k] = log(D[k])
    end
end
# Out:
# norm_table! (generic function with 1 method)

# %%
norm_table!.(G);

# %%
LOG_T = last.(G)
# Out:
# 50-element Vector{Dict{Tuple{UInt8, Vararg{UInt8}}, Float64}}:
#  Dict((0x63, 0x61) => -10.829374267484004, (0x68, 0x65) => -11.856013056527026, (0x63, 0x20, 0x6d) => -11.856013056527026, (0xd8, 0xb4, 0xd8) => -6.799631292737374, (0x70, 0x75, 0x74) => -8.211869496254481, (0xa8, 0xd8) => -5.630116377247552, (0xaf,) => -5.188790353551395, (0xd9, 0x87, 0xd8) => -6.183963528535899, (0xb3, 0x20) => -7.285637188171951, (0x74, 0x20, 0x65, 0x6e) => -8.238361111701456…)
#  Dict((0xd0, 0xb0, 0x20, 0xd0) => -6.068576192298406, (0x80, 0xd0, 0xbd, 0xd1) => -9.464620328902246, (0xb0, 0x20, 0xd1, 0x82, 0xd1) => -9.576356614532218, (0xb0, 0xd0, 0xbc, 0xd0, 0xbe) => -9.8489266930945, (0xbb, 0xd0, 0xba, 0xd0) => -10.598878403713769, (0xd0, 0xbd, 0xd1, 0x83) => -8.399933216502276, (0xb3, 0xd0, 0xb5, 0xd0, 0xbd) => -10.694960735089238, (0xd1, 0x87) => -6.414855338069508, (0xd0, 0xb3, 0xd0, 0xbb) => -8.99907445542656, (0x63, 0x61) => -12.363586693997396…)
#  Dict((0xa3,) => -6.62700088977945, (0xb9, 0x20, 0xe0) => -6.3003832441018055, (0x63, 0x61) => -12.025723947927203, (0x68, 0x65) => -10.974179170117077, (0x20, 0x72, 0x65, 0x66) => -11.927283875113948, (0x20, 0x6e) => -11.56437838142458, (0x68, 0x20) => -11.95903257342853, (0x70, 0x75, 0x74) => -11.896512216447196, (0x20, 0x62) => -11.014597749735106, (0x20, 0x63, 0x6f) => -11.46119414518935…)
#  Dict((0xd1, 0x87) => -6.579179973669785, (0xd0, 0xb3, 0xd0, 0xbb) => -8.983711849555092, (0x68, 0x65) => -11.888496461592466, (0xbe, 0x20, 0xd0, 0xba) => -9.11299219688861, (0xd0, 0xb8, 0xd0, 0xb5) => -8.185720956484822, (0xb8, 0xd0, 0xbc) => -7.950716001106798, (0x20, 0xd0, 0xb3, 0xd0, 0xb5) => -10.072926302919516, (0xb3, 0x20) => -8.69982649958371, (0x70, 0x72) => -12.801452272631426, (0x6f, 0x6c) => -12.801452272631426…)
#  Dict((0x63, 0x61, 0x76) => -10.956556507333044, (0x75, 0x72, 0x61, 0x72) => -10.985969320135416, (0x65, 0x63, 0x68) => -11.682586290610192, (0x65, 0x20, 0x73, 0x65, 0x6d) => -11.934238670224653, (0x6f, 0x72, 0x61, 0x6e) => -11.432838036878962, (0x68, 0x65) => -8.33472620470423, (0x65, 0x72, 0x20, 0x74, 0x72) => -11.159505276386593, (0x64, 0x69, 0x65, 0x6e) => -11.57915653586452, (0x6d, 0x20, 0x67) => -11.911332146644389, (0x66, 0x69, 0x63, 0x69, 0x61) => -11.097407306978553…)
#  Dict((0x6c, 0x65, 0x20, 0x6f) => -10.769492511593317, (0x64, 0x65, 0x74, 0x65) => -11.193561616635163, (0x6f, 0x20, 0x6e) => -7.88803327226299, (0x74, 0x69, 0x62) => -12.484201544934608, (0x72, 0x65, 0x64, 0x69) => -12.352406313594892, (0x6d, 0x20, 0x6e, 0x61, 0x20) => -9.693980019887842, (0x68, 0x61, 0x72, 0x6c) => -12.264553442921185, (0x74, 0x61, 0x20, 0x6b) => -11.187940571670865, (0x6b, 0x20, 0x6b) => -10.17783403507611, (0xb3, 0x20) => -12.243984709472896…)
#  Dict((0x65, 0x72, 0x20, 0x74, 0x72) => -10.536369289402977, (0x64, 0x69, 0x65, 0x6e) => -12.087260141354102, (0x74, 0x20, 0x62, 0x6c) => -9.477715811132109, (0x6c, 0x65, 0x20, 0x6f) => -10.480579714267323, (0x74, 0x69, 0x62) => -12.173640949032285, (0x72, 0x65, 0x64, 0x69) => -11.19916754255695, (0x66, 0x72, 0xc3) => -11.792098520310711, (0x6b, 0x20, 0x6b) => -10.582745174849737, (0x70, 0x72) => -7.932360968562871, (0x61, 0x6c, 0x6c, 0x65, 0x72) => -10.169923625083639…)
#  Dict((0x65, 0x72, 0x20, 0x74, 0x72) => -10.90354884793598, (0x74, 0x20, 0x62, 0x6c) => -11.70379846962694, (0x6c, 0x65, 0x20, 0x6f) => -12.856906277777172, (0x6f, 0x20, 0x6e) => -11.314745559969898, (0x61, 0x6e, 0x64, 0x61, 0x6e) => -14.132668321665106, (0x6d, 0x65, 0x68) => -9.325306134800929, (0x61, 0x6c, 0x6c, 0x65, 0x72) => -10.909700090882033, (0x6f, 0x73, 0x74, 0x65, 0x72) => -11.853566003960077, (0x66, 0x61, 0x20) => -12.472033850251568, (0x74, 0x70, 0x75, 0x74) => -11.916378878195287…)
#  Dict((0x63, 0x61) => -10.851778938233597, (0x68, 0x65) => -10.090233793252914, (0x20, 0x6f, 0x66, 0x20) => -11.375849788749608, (0x77, 0x69) => -11.426902485063192, (0xaf,) => -4.438413299891629, (0xb3, 0x20) => -11.00935506326677, (0x70, 0x72) => -11.924415740498446, (0x6f, 0x6c) => -10.619830149127614, (0x69, 0x6e, 0x75) => -11.627164217030515, (0x74, 0x65, 0x6e) => -11.815216448533455…)
#  Dict((0x63, 0x61, 0x76) => -12.322456834947005, (0x65, 0x72, 0x20, 0x74, 0x72) => -12.32203281806948, (0x74, 0x20, 0x62, 0x6c) => -12.423417591385142, (0x6c, 0x65, 0x20, 0x6f) => -10.313502114277853, (0x6f, 0x20, 0x6e) => -10.246755985679593, (0x63, 0x61, 0x74, 0x61) => -12.432622959378172, (0x6d, 0x65, 0x68) => -13.976551193741276, (0x61, 0x6c, 0x6c, 0x65, 0x72) => -11.593330685219088, (0x6f, 0x73, 0x74, 0x65, 0x72) => -12.956880909760748, (0x66, 0x61, 0x20) => -12.476520938065722…)
#  ⋮
#  Dict((0x65, 0x63, 0x68) => -10.6289934216818, (0x20, 0x6c, 0x61, 0x75) => -12.639149304122212, (0x68, 0x65) => -7.297041342986392, (0x6c, 0x69, 0x74, 0x75) => -10.124312042241165, (0x74, 0x69, 0x62) => -9.721330702015171, (0x72, 0x61, 0x74, 0x61, 0x20) => -12.138900039825565, (0x6f, 0x20, 0x6e) => -7.50189101706496, (0x63, 0x69, 0x65) => -12.46638608435933, (0x74, 0x61, 0x20, 0x6a) => -11.151811517604886, (0x61, 0x6e, 0x64, 0x61, 0x6e) => -11.935147305680042…)
#  Dict((0x75, 0x72, 0x61, 0x72) => -12.831460893608767, (0x65, 0x72, 0x20, 0x74, 0x72) => -11.497864450128258, (0x64, 0x69, 0x65, 0x6e) => -12.109969462461562, (0x74, 0x20, 0x62, 0x6c) => -10.316858687006809, (0x73, 0x61, 0x20, 0x64) => -10.995236581365724, (0x63, 0x61, 0x74, 0x61) => -8.969298975214887, (0x72, 0x65, 0x64, 0x69) => -11.893175974474627, (0x74, 0x61, 0x20, 0x6b) => -10.902880413203466, (0x66, 0x72, 0xc3) => -8.417991371533857, (0x6b, 0x20, 0x6b) => -11.07345949229498…)
#  Dict((0xd1, 0x87) => -6.3422082406235, (0xd0, 0xb3, 0xd0, 0xbb) => -10.519740454573228, (0x68, 0x65) => -11.324060439874163, (0xbe, 0x20, 0xd0, 0xba) => -11.101636704822816, (0xd0, 0xb8, 0xd0, 0xb5) => -9.022592447493976, (0xb8, 0xd0, 0xbc) => -8.174520700649195, (0x20, 0xd0, 0xb3, 0xd0, 0xb5) => -9.22328028312759, (0xb3, 0x20) => -10.644907629500423, (0x6f, 0x6c) => -11.654699937764338, (0xbe, 0xd1, 0x82, 0xd0, 0xbe) => -11.847674334840129…)
#  Dict((0x63, 0x61, 0x76) => -12.203936597217258, (0x67, 0x20, 0x62, 0x61) => -7.723163917368306, (0x65, 0x63, 0x68) => -12.303986170743086, (0x6f, 0x72, 0x61, 0x6e) => -12.598319636294802, (0x68, 0x65) => -8.306714878491828, (0x6d, 0x20, 0x67) => -12.924930703892432, (0x6c, 0x69, 0x74, 0x75) => -12.408292875505765, (0x74, 0x69, 0x62) => -10.116398215146587, (0x72, 0x61, 0x74, 0x61, 0x20) => -11.67519565378551, (0x6f, 0x20, 0x6e) => -6.857095266909735…)
#  Dict((0x63, 0x61, 0x76) => -13.05859261380348, (0x75, 0x72, 0x61, 0x72) => -13.163521402253103, (0x6c, 0x65, 0x20, 0x6f) => -10.353033651422312, (0x6f, 0x20, 0x6e) => -11.040593387903629, (0x61, 0x6e, 0x64, 0x61, 0x6e) => -10.815695760874217, (0x74, 0x61, 0x20, 0x6b) => -10.92915870259158, (0x6d, 0x65, 0x68) => -11.334246350749117, (0x61, 0x6c, 0x6c, 0x65, 0x72) => -11.26569559864735, (0x6f, 0x73, 0x74, 0x65, 0x72) => -13.685128286663344, (0x66, 0x61, 0x20) => -10.400500004627188…)
#  Dict((0xd1, 0x87) => -6.590721311266489, (0xd0, 0xb3, 0xd0, 0xbb) => -9.442179525651191, (0x68, 0x65) => -12.234492068730415, (0xbe, 0x20, 0xd0, 0xba) => -9.521038391172302, (0xb8, 0xd0, 0xbc) => -7.9788324175291265, (0x20, 0xd0, 0xb3, 0xd0, 0xb5) => -10.351479717304526, (0xb3, 0x20) => -9.621788689189346, (0x70, 0x72) => -11.549296876675179, (0x6f, 0x6c) => -12.055106283647543, (0xbe, 0xd1, 0x82, 0xd0, 0xbe) => -10.229945536650607…)
#  Dict((0x67, 0x20, 0x62, 0x61) => -9.675989483356071, (0x63, 0x61) => -8.054847627601534, (0x20, 0x6c, 0x61, 0x75) => -11.041899474486645, (0x6e, 0x20, 0x74) => -6.333539898334515, (0x74, 0x6f, 0x6d, 0x20) => -7.417961577932608, (0x68, 0x65) => -7.898491417993033, (0x6d, 0x20, 0x67) => -9.076621022478328, (0x63, 0x20, 0x6d) => -8.450835858589624, (0x79, 0x6c, 0x61) => -11.546175828331371, (0x69, 0x61, 0x20, 0x73) => -10.904398526059547…)
#  Dict((0x98,) => -4.308298642922862, (0x66,) => -11.944311505790495, (0xaa,) => -6.92201301906536, (0xa8, 0xd7) => -4.635756486331553, (0xd7, 0xa8, 0xd7) => -4.635756486331553, (0xa3,) => -7.56853832908322, (0xd7, 0xa2) => -3.8566670001969237, (0x97, 0x20) => -9.007010296959605, (0x9e, 0xd7) => -5.185877347371816, (0x65,) => -10.142018242843985…)
#  Dict((0x62, 0x6f, 0x6f) => -11.48119257997627, (0x63, 0x61) => -9.390386580702415, (0x79, 0x61) => -10.382468822148365, (0x6e, 0x63, 0x65) => -9.903712376195543, (0x74, 0x6f, 0x6d, 0x20) => -11.63229124812564, (0x68, 0x65) => -9.31322308252663, (0x63, 0x20, 0x6d) => -10.425308451923591, (0x6e, 0x73, 0x20) => -10.704327295043264, (0x6f, 0x20, 0x6e) => -10.450588294026442, (0x70, 0x75, 0x74) => -8.325906167681218…)

# %%
DEFAULT_LOGP = (minimum.(values.(last.((G))))|>minimum)
# Out:
# -16.900214584493458

# %%
function likelihood(t, logt, default_logp=DEFAULT_LOGP)
    sc = 0.
    for (code, p) in t
        sc += p * get(logt, code, default_logp)
    end
    sc
end
# Out:
# likelihood (generic function with 2 methods)

# %%
function detector_lh(text; ngram=5, languages=LANGS, logtable=LOG_T)
    t = merged_ngrams(text, ngram)
    lhs = likelihood.(Ref(t), logtable)
    languages[argmax(lhs)]
end
# Out:
# detector_lh (generic function with 1 method)

# %%
include("benchmark.jl")
# Out:
# showtable (generic function with 2 methods)

# %%
WV = WikiDataSet("corpus/wikipedia/test", langs=LANGS)
TV = TatoebaDataset("corpus/tatoeba", "tatoeba_test.txt", langs=LANGS)
# Out:
# 521469-element TatoebaDataset:
#              "Pardonu, permesu al mi indiki tri erarojn en la supra artikolo." => "epo"
#                                           "Mi veturigos vin al la flughaveno." => "epo"
#                                                                  "Kio mankas?" => "epo"
#                                             "Aĥ, kiam ili renkontiĝos denove?" => "epo"
#  "Kiam mi estis infano, mi pasigis multajn horojn legante sola en mia ĉambro." => "epo"
#                                               "Ŝajnas, ke la trajno malfruas." => "epo"
#                                                                 "Venu rapide!" => "epo"
#                                                    "Li montris al mi albumon." => "epo"
#                                                              "Estis du kukoj." => "epo"
#                                       "Mia filo scipovas jam nombri ĝis cent." => "epo"
#                                                                                ⋮
#                                                       "Tohle pivo je výborné." => "ces"
#                                               "Musíš se řídit matčinou radou." => "ces"
#                                              "Tom potvrdil všechno, co řekli." => "ces"
#                                                         "Byl obnoven pořádek." => "ces"
#                                               "Medvědi jsou velmi nebezpeční." => "ces"
#                                      "Buď vděčný za to, že můžeš být s Tomem." => "ces"
#                                                 "Neštěstí nechodí nikdy samo." => "ces"
#                                                     "Problémem nejsou peníze." => "ces"
#                                          "Tom koupil několik bochníků chleba." => "ces"

# %%
WB = benchmark(
    # "likelihood-n5"=>detector_lh, 
    "likelihood-n4"=>t->detector_lh(t, ngram=4),
    "likelihood-n3"=>t->detector_lh(t, ngram=3),
dataset=WV, languages=LANGS)
# Out:
# likelihood-n4
# 114.825043 seconds (1.63 G allocations: 28.842 GiB, 4.03% gc time, 0.62% compilation time)
# likelihood-n3
#  68.638885 seconds (885.20 M allocations: 16.352 GiB, 3.85% gc time, 0.09% compilation time)
# 2-element Vector{Any}:
#  "likelihood-n4" => [1.0, 0.99, 1.0, 0.98, 0.995, 0.98, 0.985, 0.97, 0.995, 1.0  …  1.0, 0.99, 0.98, 0.995, 0.985, 0.985, 1.0, 0.955, 0.98, 0.995]
#  "likelihood-n3" => [1.0, 0.99, 1.0, 0.925, 0.995, 0.985, 0.975, 0.965, 1.0, 1.0  …  1.0, 0.99, 0.98, 0.995, 0.985, 0.985, 0.995, 0.965, 0.98, 1.0]

# %%
showtable(WB, LANGS, threshold=-0.5)
# Out:
# |               | Average | ara     | bel    | ben     | bul    | cat    | ces    | dan    | deu    | ell     | eng     | epo     | fas    | fin    | fra     | hau    | hbs   | heb     | hin    | hun     | ido    | ina    | isl    | ita    | jpn    | kab    | kor    | kur    | lat    | lit     | mar    | mkd    | msa    | nds    | nld    | nor    | pol     | por    | ron    | rus    | slk    | spa     | swa    | swe    | tat    | tgl    | tur    | ukr     | vie    | yid    | zho     |
# |---------------|---------|---------|--------|---------|--------|--------|--------|--------|--------|---------|---------|---------|--------|--------|---------|--------|-------|---------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|---------|
# | likelihood-n4 |  95.59% | 100.00% | 99.00% | 100.00% | 98.00% | 99.50% | 98.00% | 98.50% | 97.00% |  99.50% | 100.00% | 100.00% | 99.00% | 99.00% | 100.00% | 98.50% | 5.00% | 100.00% | 87.50% |  99.00% | 87.50% | 92.50% | 98.50% | 99.00% | 94.00% | 98.50% | 93.50% | 99.00% | 97.00% | 100.00% | 92.00% | 98.00% | 99.00% | 97.00% | 97.00% | 91.50% |  99.00% | 99.00% | 91.00% | 99.50% | 93.00% | 100.00% | 99.00% | 98.00% | 99.50% | 98.50% | 98.50% | 100.00% | 95.50% | 98.00% |  99.50% |
# | likelihood-n3 |  95.27% | 100.00% | 99.00% | 100.00% | 92.50% | 99.50% | 98.50% | 97.50% | 96.50% | 100.00% | 100.00% |  99.50% | 99.00% | 99.00% | 100.00% | 99.00% | 5.00% | 100.00% | 80.00% | 100.00% | 87.00% | 84.50% | 98.50% | 98.00% | 94.50% | 99.00% | 93.50% | 99.00% | 96.50% | 100.00% | 96.00% | 97.00% | 99.00% | 98.50% | 96.50% | 91.00% | 100.00% | 98.00% | 89.00% | 99.50% | 96.00% | 100.00% | 99.00% | 98.00% | 99.50% | 98.50% | 98.50% |  99.50% | 96.50% | 98.00% | 100.00% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x31, 0x30, 0x30, 0x2e, 0x30, 0x30, 0x25, 0x20, 0x7c, 0x0a])

# %%
hbs = WikiDataSet("corpus/wikipedia/test", langs=["hbs"]);

# %%
x,y = hbs[rand(1:length(hbs))]
detector_lh(x, ngram=4), y
# Out:
# ("mkd", "hbs")

# %%
WB2 = benchmark(
    "likelihood-n5"=>detector_lh, 
    # "likelihood-n4"=>t->detector_lh(t, ngram=4),
    # "likelihood-n3"=>t->detector_lh(t, ngram=3),
dataset=WV, languages=("mkd", "hbs"))
# Out:
# likelihood-n5
#   7.841419 seconds (90.28 M allocations: 1.665 GiB, 3.70% gc time, 1.24% compilation time)
# 1-element Vector{Any}:
#  "likelihood-n5" => [0.985, 0.065]

# %%
# import Pkg; Pkg.add("Tables"); Pkg.add("MarkdownTables"); Pkg.add("DataFrames")

# %%
# using ProgressMeter
include("datasetloader.jl")
include("benchmark.jl")
# Out:
# showtable (generic function with 2 methods)

# %%
WV = WikiDataSet("corpus/wikipedia/test", langs=LANGS)
TV = TatoebaDataset("corpus/tatoeba", "tatoeba_test.txt", langs=LANGS)
# Out:
# 521469-element TatoebaDataset:
#              "Pardonu, permesu al mi indiki tri erarojn en la supra artikolo." => "epo"
#                                           "Mi veturigos vin al la flughaveno." => "epo"
#                                                                  "Kio mankas?" => "epo"
#                                             "Aĥ, kiam ili renkontiĝos denove?" => "epo"
#  "Kiam mi estis infano, mi pasigis multajn horojn legante sola en mia ĉambro." => "epo"
#                                               "Ŝajnas, ke la trajno malfruas." => "epo"
#                                                                 "Venu rapide!" => "epo"
#                                                    "Li montris al mi albumon." => "epo"
#                                                              "Estis du kukoj." => "epo"
#                                       "Mia filo scipovas jam nombri ĝis cent." => "epo"
#                                                                                ⋮
#                                                       "Tohle pivo je výborné." => "ces"
#                                               "Musíš se řídit matčinou radou." => "ces"
#                                              "Tom potvrdil všechno, co řekli." => "ces"
#                                                         "Byl obnoven pořádek." => "ces"
#                                               "Medvědi jsou velmi nebezpeční." => "ces"
#                                      "Buď vděčný za to, že můžeš být s Tomem." => "ces"
#                                                 "Neštěstí nechodí nikdy samo." => "ces"
#                                                     "Problémem nejsou peníze." => "ces"
#                                          "Tom koupil několik bochníků chleba." => "ces"

# %%
# import Pkg; Pkg.add(["LanguageFinder", "LanguageDetect", "Languages"])

# %%
# import LanguageFinder: LanguageFind
# detector_lf(t) = LanguageFind(t, 0).lang
import LanguageDetect: detect
detector_ld(t) = first(detect(t)).language
import Languages: LanguageDetector, isocode
Languages_detector = LanguageDetector()
function detector_ls(t)
    l = Languages_detector(t) |> first
    if l == nothing
        return ""
    else
        return l |> isocode
    end
end
using Logging
Logging.disable_logging(Logging.Info)
# Out:
# LogLevel(1)

# %%
include("detector.jl")
detector_lh
# Out:
# WARNING: redefinition of constant TLANGS. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant WLANGS. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant LANGS. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant WLANGMAP. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant TLANGMAP. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant REV_WLANGMAP. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant REV_TLANGMAP. This may fail, cause incorrect answers, or produce other errors.
# detector_lh (generic function with 1 method)

# %% [markdown]
# ## tatoeba

# %%
TB = benchmark(
"detector_ngram1"=>t->detector_lh(t, ngram=1),
"detector_ngram2"=>t->detector_lh(t, ngram=2),
"detector_ngram3"=>t->detector_lh(t, ngram=3),
"detector_ngram4"=>t->detector_lh(t, ngram=4),
"detector_ngram5"=>detector_lh,
# "Languages.jl"=>detector_ls, 
# "LanguageDetect.jl"=>detector_ld,
 dataset=TV, languages=LANGS)
# Out:
# detector_ngram1
#  27.674649 seconds (40.47 M allocations: 3.161 GiB, 1.71% gc time, 0.84% compilation time)
# detector_ngram2
#  80.388989 seconds (63.23 M allocations: 5.854 GiB, 1.01% gc time, 0.08% compilation time)
# detector_ngram3146.659879 seconds (85.08 M allocations: 8.258 GiB, 0.75% gc time, 0.04% compilation time)
# detector_ngram4207.225401 seconds (106.08 M allocations: 10.882 GiB, 0.68% gc time, 0.03% compilation time)
# detector_ngram5
# 262.937559 seconds (126.62 M allocations: 14.058 GiB, 0.53% gc time, 0.02% compilation time)
# 5-element Vector{Any}:
#  "detector_ngram1" => [0.9889075630252101, 0.9441997063142438, 1.0, 0.7540192926045016, 0.5913461538461539, 0.5151265126512651, 0.24768120920645825, 0.19771960815802153, 1.0, 0.4165384277172001  …  0.10441080319871247, 0.7978187919463087, 0.7558667676003028, 0.8667601683029453, 0.8221925133689839, 0.8296265674521152, 0.7718668407310705, 0.9966273187183811, 0.9827586206896551, 1.0]
#  "detector_ngram2" => [0.9889075630252101, 0.9559471365638766, 1.0, 0.7588424437299035, 0.8509615384615384, 0.6784928492849285, 0.5197526623153556, 0.7646378673518548, 1.0, 0.8963902567710166  …  0.52984962027863, 0.9379194630872483, 0.8716881150643452, 0.8948106591865358, 0.9494652406417112, 0.9209315143998897, 0.7808964316797214, 0.9966273187183811, 0.9839080459770115, 1.0]
#  "detector_ngram3" => [0.9905882352941177, 0.9588839941262849, 1.0, 0.7741157556270096, 0.8990384615384616, 0.8338833883388339, 0.7014771556166266, 0.9562871366629195, 1.0, 0.9656282975729863  …  0.8274908213046321, 0.9739932885906041, 0.9288417865253595, 0.908835904628331, 0.9770053475935829, 0.9698222405952873, 0.8510661444734552, 0.9983136593591906, 0.9873563218390805, 1.0]
#  "detector_ngram4" => [0.9909243697478992, 0.9662261380323054, 1.0, 0.7990353697749196, 0.9086538461538461, 0.8822882288228823, 0.7863277224321539, 0.9815641560944275, 1.0, 0.9807421737601125  …  0.8963939043403912, 0.9781879194630873, 0.9428463285389856, 0.9130434782608695, 0.9855614973262032, 0.9776767259198016, 0.8853350739773717, 0.9991568296795953, 0.9873563218390805, 1.0]
#  "detector_ngram5" => [0.9909243697478992, 0.9632892804698973, 1.0, 0.7982315112540193, 0.9134615384615384, 0.897964796479648, 0.8155273102026795, 0.9850329211498314, 1.0, 0.9845233907843827  …  0.9077603983302318, 0.9798657718120806, 0.9390613171839516, 0.9172510518934082, 0.9866310160427807, 0.9795232189610031, 0.8914273281114012, 0.9991568296795953, 0.9885057471264368, 1.0]

# %%
showtable(TB, LANGS)
# Out:
# |                 | Average | ara    | bel    | ben     | bul    | cat    | ces    | dan    | deu    | ell     | eng    | epo    | fas    | fin    | fra    | hau    | hbs    | heb    | hin    | hun    | ido    | ina    | isl    | ita    | jpn    | kab    | kor     | kur    | lat    | lit    | mar    | mkd    | msa    | nds    | nld    | nor    | pol    | por    | ron    | rus    | slk    | spa    | swa    | swe    | tat    | tgl    | tur    | ukr    | vie    | yid    | zho     |
# |-----------------|---------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|
# | detector_ngram1 |  71.15% | 98.89% | 94.42% | 100.00% | 75.40% | 59.13% | 51.51% | 24.77% | 19.77% | 100.00% | 41.65% | 51.65% | 97.50% | 71.49% | 14.85% | 71.49% |  1.13% | 96.28% | 60.37% | 68.83% | 93.06% | 23.64% | 93.67% |  9.25% | 99.91% | 81.44% | 100.00% | 98.24% | 63.75% | 82.64% | 83.98% | 93.85% | 71.46% | 69.20% | 49.14% | 66.98% | 90.86% | 45.15% | 83.05% | 80.37% | 85.94% | 10.44% | 79.78% | 75.59% | 86.68% | 82.22% | 82.96% | 77.19% | 99.66% | 98.28% | 100.00% |
# | detector_ngram2 |  86.43% | 98.89% | 95.59% | 100.00% | 75.88% | 85.10% | 67.85% | 51.98% | 76.46% | 100.00% | 89.64% | 66.91% | 98.24% | 94.63% | 79.56% | 96.33% |  2.59% | 97.72% | 67.19% | 92.63% | 96.06% | 84.17% | 97.44% | 68.11% | 99.95% | 95.90% | 100.00% | 98.72% | 89.17% | 93.50% | 81.66% | 91.19% | 92.86% | 91.42% | 88.80% | 84.24% | 97.38% | 79.42% | 89.89% | 85.34% | 92.46% | 52.98% | 93.79% | 87.17% | 89.48% | 94.95% | 92.09% | 78.09% | 99.66% | 98.39% | 100.00% |
# | detector_ngram3 |  91.60% | 99.06% | 95.89% | 100.00% | 77.41% | 89.90% | 83.39% | 70.15% | 95.63% | 100.00% | 96.56% | 88.50% | 98.90% | 98.22% | 94.36% | 97.89% |  9.27% | 98.81% | 68.37% | 96.86% | 94.00% | 93.99% | 98.34% | 93.37% | 99.95% | 98.70% | 100.00% | 98.88% | 93.95% | 98.28% | 81.00% | 84.84% | 96.53% | 94.94% | 95.24% | 85.86% | 98.57% | 93.92% | 94.16% | 89.54% | 94.63% | 82.75% | 97.40% | 92.88% | 90.88% | 97.70% | 96.98% | 85.11% | 99.83% | 98.74% | 100.00% |
# | detector_ngram4 |  92.97% | 99.09% | 96.62% | 100.00% | 79.90% | 90.87% | 88.23% | 78.63% | 98.16% | 100.00% | 98.07% | 96.39% | 99.12% | 98.56% | 96.61% | 98.72% | 26.23% | 99.05% | 72.57% | 97.82% | 91.37% | 95.09% | 98.79% | 96.12% | 99.96% | 99.04% | 100.00% | 98.72% | 93.83% | 98.93% | 76.75% | 78.51% | 97.30% | 95.71% | 96.44% | 85.17% | 98.78% | 96.54% | 95.54% | 90.49% | 94.29% | 89.64% | 97.82% | 94.28% | 91.30% | 98.56% | 97.77% | 88.53% | 99.92% | 98.74% | 100.00% |
# | detector_ngram5 |  93.19% | 99.09% | 96.33% | 100.00% | 79.82% | 91.35% | 89.80% | 81.55% | 98.50% | 100.00% | 98.45% | 97.28% | 99.04% | 98.67% | 97.01% | 98.81% | 37.47% | 99.20% | 72.83% | 98.00% | 90.24% | 94.82% | 98.94% | 96.36% | 99.96% | 99.04% | 100.00% | 98.72% | 93.71% | 98.99% | 76.69% | 71.14% | 97.49% | 95.49% | 96.65% | 84.36% | 98.83% | 96.83% | 95.42% | 90.02% | 93.49% | 90.78% | 97.99% | 93.91% | 91.73% | 98.66% | 97.95% | 89.14% | 99.92% | 98.85% | 100.00% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x31, 0x30, 0x30, 0x2e, 0x30, 0x30, 0x25, 0x20, 0x7c, 0x0a])

# %%
showtable(TB, LANGS, threshold=0.)
# Out:
# 50 columns in total, 50 columns left.
# |                 | Average | ara    | bel    | ben     | bul    | cat    | ces    | dan    | deu    | ell     | eng    | epo    | fas    | fin    | fra    | hau    | hbs    | heb    | hin    | hun    | ido    | ina    | isl    | ita    | jpn    | kab    | kor     | kur    | lat    | lit    | mar    | mkd    | msa    | nds    | nld    | nor    | pol    | por    | ron    | rus    | slk    | spa    | swa    | swe    | tat    | tgl    | tur    | ukr    | vie    | yid    | zho     |
# |-----------------|---------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|
# | detector_ngram1 |  71.15% | 98.89% | 94.42% | 100.00% | 75.40% | 59.13% | 51.51% | 24.77% | 19.77% | 100.00% | 41.65% | 51.65% | 97.50% | 71.49% | 14.85% | 71.49% |  1.13% | 96.28% | 60.37% | 68.83% | 93.06% | 23.64% | 93.67% |  9.25% | 99.91% | 81.44% | 100.00% | 98.24% | 63.75% | 82.64% | 83.98% | 93.85% | 71.46% | 69.20% | 49.14% | 66.98% | 90.86% | 45.15% | 83.05% | 80.37% | 85.94% | 10.44% | 79.78% | 75.59% | 86.68% | 82.22% | 82.96% | 77.19% | 99.66% | 98.28% | 100.00% |
# | detector_ngram2 |  86.43% | 98.89% | 95.59% | 100.00% | 75.88% | 85.10% | 67.85% | 51.98% | 76.46% | 100.00% | 89.64% | 66.91% | 98.24% | 94.63% | 79.56% | 96.33% |  2.59% | 97.72% | 67.19% | 92.63% | 96.06% | 84.17% | 97.44% | 68.11% | 99.95% | 95.90% | 100.00% | 98.72% | 89.17% | 93.50% | 81.66% | 91.19% | 92.86% | 91.42% | 88.80% | 84.24% | 97.38% | 79.42% | 89.89% | 85.34% | 92.46% | 52.98% | 93.79% | 87.17% | 89.48% | 94.95% | 92.09% | 78.09% | 99.66% | 98.39% | 100.00% |
# | detector_ngram3 |  91.60% | 99.06% | 95.89% | 100.00% | 77.41% | 89.90% | 83.39% | 70.15% | 95.63% | 100.00% | 96.56% | 88.50% | 98.90% | 98.22% | 94.36% | 97.89% |  9.27% | 98.81% | 68.37% | 96.86% | 94.00% | 93.99% | 98.34% | 93.37% | 99.95% | 98.70% | 100.00% | 98.88% | 93.95% | 98.28% | 81.00% | 84.84% | 96.53% | 94.94% | 95.24% | 85.86% | 98.57% | 93.92% | 94.16% | 89.54% | 94.63% | 82.75% | 97.40% | 92.88% | 90.88% | 97.70% | 96.98% | 85.11% | 99.83% | 98.74% | 100.00% |
# | detector_ngram4 |  92.97% | 99.09% | 96.62% | 100.00% | 79.90% | 90.87% | 88.23% | 78.63% | 98.16% | 100.00% | 98.07% | 96.39% | 99.12% | 98.56% | 96.61% | 98.72% | 26.23% | 99.05% | 72.57% | 97.82% | 91.37% | 95.09% | 98.79% | 96.12% | 99.96% | 99.04% | 100.00% | 98.72% | 93.83% | 98.93% | 76.75% | 78.51% | 97.30% | 95.71% | 96.44% | 85.17% | 98.78% | 96.54% | 95.54% | 90.49% | 94.29% | 89.64% | 97.82% | 94.28% | 91.30% | 98.56% | 97.77% | 88.53% | 99.92% | 98.74% | 100.00% |
# | detector_ngram5 |  93.19% | 99.09% | 96.33% | 100.00% | 79.82% | 91.35% | 89.80% | 81.55% | 98.50% | 100.00% | 98.45% | 97.28% | 99.04% | 98.67% | 97.01% | 98.81% | 37.47% | 99.20% | 72.83% | 98.00% | 90.24% | 94.82% | 98.94% | 96.36% | 99.96% | 99.04% | 100.00% | 98.72% | 93.71% | 98.99% | 76.69% | 71.14% | 97.49% | 95.49% | 96.65% | 84.36% | 98.83% | 96.83% | 95.42% | 90.02% | 93.49% | 90.78% | 97.99% | 93.91% | 91.73% | 98.66% | 97.95% | 89.14% | 99.92% | 98.85% | 100.00% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x31, 0x30, 0x30, 0x2e, 0x30, 0x30, 0x25, 0x20, 0x7c, 0x0a])

# %%
showtable(TB, LANGS, threshold=0.5)
# Out:
# 50 columns in total, 40 columns left.
# |                 | Average | ara    | bel    | ben     | bul    | cat    | ces    | ell     | epo    | fas    | fin    | hau    | heb    | hin    | hun    | ido    | isl    | jpn    | kab    | kor     | kur    | lat    | lit    | mar    | mkd    | msa    | nds    | nor    | pol    | ron    | rus    | slk    | swa    | swe    | tat    | tgl    | tur    | ukr    | vie    | yid    | zho     |
# |-----------------|---------|--------|--------|---------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|
# | detector_ngram1 |  82.94% | 98.89% | 94.42% | 100.00% | 75.40% | 59.13% | 51.51% | 100.00% | 51.65% | 97.50% | 71.49% | 71.49% | 96.28% | 60.37% | 68.83% | 93.06% | 93.67% | 99.91% | 81.44% | 100.00% | 98.24% | 63.75% | 82.64% | 83.98% | 93.85% | 71.46% | 69.20% | 66.98% | 90.86% | 83.05% | 80.37% | 85.94% | 79.78% | 75.59% | 86.68% | 82.22% | 82.96% | 77.19% | 99.66% | 98.28% | 100.00% |
# | detector_ngram2 |  91.19% | 98.89% | 95.59% | 100.00% | 75.88% | 85.10% | 67.85% | 100.00% | 66.91% | 98.24% | 94.63% | 96.33% | 97.72% | 67.19% | 92.63% | 96.06% | 97.44% | 99.95% | 95.90% | 100.00% | 98.72% | 89.17% | 93.50% | 81.66% | 91.19% | 92.86% | 91.42% | 84.24% | 97.38% | 89.89% | 85.34% | 92.46% | 93.79% | 87.17% | 89.48% | 94.95% | 92.09% | 78.09% | 99.66% | 98.39% | 100.00% |
# | detector_ngram3 |  93.87% | 99.06% | 95.89% | 100.00% | 77.41% | 89.90% | 83.39% | 100.00% | 88.50% | 98.90% | 98.22% | 97.89% | 98.81% | 68.37% | 96.86% | 94.00% | 98.34% | 99.95% | 98.70% | 100.00% | 98.88% | 93.95% | 98.28% | 81.00% | 84.84% | 96.53% | 94.94% | 85.86% | 98.57% | 94.16% | 89.54% | 94.63% | 97.40% | 92.88% | 90.88% | 97.70% | 96.98% | 85.11% | 99.83% | 98.74% | 100.00% |
# | detector_ngram4 |  94.43% | 99.09% | 96.62% | 100.00% | 79.90% | 90.87% | 88.23% | 100.00% | 96.39% | 99.12% | 98.56% | 98.72% | 99.05% | 72.57% | 97.82% | 91.37% | 98.79% | 99.96% | 99.04% | 100.00% | 98.72% | 93.83% | 98.93% | 76.75% | 78.51% | 97.30% | 95.71% | 85.17% | 98.78% | 95.54% | 90.49% | 94.29% | 97.82% | 94.28% | 91.30% | 98.56% | 97.77% | 88.53% | 99.92% | 98.74% | 100.00% |
# | detector_ngram5 |  94.27% | 99.09% | 96.33% | 100.00% | 79.82% | 91.35% | 89.80% | 100.00% | 97.28% | 99.04% | 98.67% | 98.81% | 99.20% | 72.83% | 98.00% | 90.24% | 98.94% | 99.96% | 99.04% | 100.00% | 98.72% | 93.71% | 98.99% | 76.69% | 71.14% | 97.49% | 95.49% | 84.36% | 98.83% | 95.42% | 90.02% | 93.49% | 97.99% | 93.91% | 91.73% | 98.66% | 97.95% | 89.14% | 99.92% | 98.85% | 100.00% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x31, 0x30, 0x30, 0x2e, 0x30, 0x30, 0x25, 0x20, 0x7c, 0x0a])

# %% [markdown]
# ## wikipedia

# %%
WB = benchmark(
"detector_ngram1"=>t->detector_lh(t, ngram=1),
"detector_ngram2"=>t->detector_lh(t, ngram=2),
"detector_ngram3"=>t->detector_lh(t, ngram=3),
"detector_ngram4"=>t->detector_lh(t, ngram=4),
"detector_ngram5"=>detector_lh,
# "Languages.jl"=>detector_ls, 
# "LanguageDetect.jl"=>detector_ld,
 dataset=WV, languages=LANGS)
# Out:
# detector_ngram1
#   5.737565 seconds (18.98 M allocations: 1.299 GiB, 3.15% gc time, 1.45% compilation time)
# detector_ngram2 13.269079 seconds (37.25 M allocations: 2.512 GiB, 2.36% gc time, 0.45% compilation time)
# detector_ngram3 28.653480 seconds (55.49 M allocations: 3.933 GiB, 1.62% gc time, 0.23% compilation time)
# detector_ngram4
#  49.287240 seconds (73.71 M allocations: 5.453 GiB, 1.26% gc time, 0.12% compilation time)
# detector_ngram5
#  78.458837 seconds (91.91 M allocations: 7.130 GiB, 1.01% gc time, 0.08% compilation time)
# 5-element Vector{Any}:
#  "detector_ngram1" => [0.995, 0.99, 1.0, 0.915, 1.0, 0.605, 0.06, 0.015, 1.0, 0.305  …  0.03, 0.94, 0.96, 0.965, 0.865, 0.98, 0.965, 0.965, 0.975, 1.0]
#  "detector_ngram2" => [0.995, 0.99, 1.0, 0.96, 1.0, 0.86, 0.79, 0.88, 1.0, 0.985  …  0.87, 0.98, 0.98, 0.97, 0.985, 0.985, 0.98, 0.955, 0.97, 1.0]
#  "detector_ngram3" => [0.995, 0.995, 1.0, 0.98, 1.0, 0.945, 0.915, 0.955, 1.0, 1.0  …  0.99, 0.995, 0.98, 0.99, 0.985, 0.99, 0.995, 0.965, 0.965, 0.995]
#  "detector_ngram4" => [0.995, 0.995, 1.0, 0.985, 1.0, 0.96, 0.975, 0.965, 1.0, 1.0  …  0.995, 0.995, 0.98, 0.99, 0.985, 0.99, 1.0, 0.965, 0.975, 0.995]
#  "detector_ngram5" => [0.995, 0.995, 1.0, 0.985, 1.0, 0.96, 0.985, 0.965, 1.0, 1.0  …  1.0, 0.995, 0.985, 0.99, 0.985, 0.99, 1.0, 0.965, 0.98, 0.995]

# %%
showtable(WB, LANGS)
# Out:
# |                 | Average | ara    | bel    | ben     | bul    | cat     | ces    | dan    | deu    | ell     | eng     | epo     | fas     | fin    | fra     | hau    | hbs    | heb     | hin    | hun    | ido    | ina    | isl    | ita     | jpn    | kab    | kor    | kur    | lat    | lit     | mar    | mkd    | msa    | nds    | nld    | nor    | pol    | por    | ron    | rus    | slk    | spa     | swa    | swe    | tat    | tgl    | tur    | ukr     | vie    | yid    | zho     |
# |-----------------|---------|--------|--------|---------|--------|---------|--------|--------|--------|---------|---------|---------|---------|--------|---------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|---------|
# | detector_ngram1 |  75.78% | 99.50% | 99.00% | 100.00% | 91.50% | 100.00% | 60.50% |  6.00% |  1.50% | 100.00% |  30.50% |  50.00% |  99.00% | 79.50% |       - | 87.50% |  5.00% | 100.00% | 25.50% | 95.50% | 93.00% | 17.50% | 96.00% |   3.00% | 93.50% | 90.50% | 97.50% | 99.00% | 82.50% |  98.00% | 99.50% | 96.50% | 84.50% | 96.50% | 40.50% | 88.50% | 95.50% | 40.50% | 85.50% | 97.50% | 98.50% |   3.00% | 94.00% | 96.00% | 96.50% | 86.50% | 98.00% |  96.50% | 96.50% | 97.50% | 100.00% |
# | detector_ngram2 |  93.43% | 99.50% | 99.00% | 100.00% | 96.00% | 100.00% | 86.00% | 79.00% | 88.00% | 100.00% |  98.50% |  86.00% |  99.50% | 99.00% |  95.00% | 95.50% |  3.50% | 100.00% | 76.00% | 98.00% | 94.00% | 86.50% | 98.00% |  91.50% | 95.00% | 96.50% | 97.00% | 99.00% | 97.00% | 100.00% | 95.50% | 97.00% | 99.00% | 99.00% | 94.50% | 95.00% | 97.50% | 90.00% | 87.00% | 99.50% | 97.00% |  87.00% | 98.00% | 98.00% | 97.00% | 98.50% | 98.50% |  98.00% | 95.50% | 97.00% | 100.00% |
# | detector_ngram3 |  95.84% | 99.50% | 99.50% | 100.00% | 98.00% | 100.00% | 94.50% | 91.50% | 95.50% | 100.00% | 100.00% |  98.50% | 100.00% | 99.00% | 100.00% | 99.00% | 11.50% | 100.00% | 83.50% | 98.50% | 93.50% | 91.00% | 98.50% |  99.50% | 97.00% | 98.50% | 97.00% | 99.00% | 98.00% | 100.00% | 94.00% | 97.50% | 99.50% | 99.00% | 96.50% | 97.00% | 99.00% | 98.50% | 89.00% | 99.50% | 97.00% |  99.00% | 99.50% | 98.00% | 99.00% | 98.50% | 99.00% |  99.50% | 96.50% | 96.50% |  99.50% |
# | detector_ngram4 |  97.83% | 99.50% | 99.50% | 100.00% | 98.50% | 100.00% | 96.00% | 97.50% | 96.50% | 100.00% | 100.00% | 100.00% | 100.00% | 99.00% | 100.00% | 99.50% | 94.00% | 100.00% | 90.50% | 99.00% | 93.50% | 93.00% | 98.50% |  99.50% | 97.50% | 99.00% | 97.00% | 99.00% | 98.00% | 100.00% | 88.00% | 96.50% | 99.50% | 98.00% | 97.00% | 95.50% | 99.00% | 99.50% | 90.00% | 99.50% | 97.50% |  99.50% | 99.50% | 98.00% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 97.50% |  99.50% |
# | detector_ngram5 |  97.97% | 99.50% | 99.50% | 100.00% | 98.50% | 100.00% | 96.00% | 98.50% | 96.50% | 100.00% | 100.00% | 100.00% | 100.00% | 99.00% | 100.00% | 99.50% | 94.00% | 100.00% | 92.50% | 99.00% | 94.50% | 93.50% | 98.50% | 100.00% | 97.50% | 99.00% | 97.00% | 99.00% | 98.50% | 100.00% | 88.00% | 97.00% | 99.50% | 96.00% | 97.50% | 96.00% | 99.00% | 99.50% | 90.50% | 99.50% | 97.50% | 100.00% | 99.50% | 98.50% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 98.00% |  99.50% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x20, 0x39, 0x39, 0x2e, 0x35, 0x30, 0x25, 0x20, 0x7c, 0x0a])

# %%
showtable(WB, LANGS, threshold=0.)
# Out:
# 50 columns in total, 49 columns left.
# |                 | Average | ara    | bel    | ben     | bul    | cat     | ces    | dan    | deu    | ell     | eng     | epo     | fas     | fin    | hau    | hbs    | heb     | hin    | hun    | ido    | ina    | isl    | ita     | jpn    | kab    | kor    | kur    | lat    | lit     | mar    | mkd    | msa    | nds    | nld    | nor    | pol    | por    | ron    | rus    | slk    | spa     | swa    | swe    | tat    | tgl    | tur    | ukr     | vie    | yid    | zho     |
# |-----------------|---------|--------|--------|---------|--------|---------|--------|--------|--------|---------|---------|---------|---------|--------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|---------|
# | detector_ngram1 |  77.33% | 99.50% | 99.00% | 100.00% | 91.50% | 100.00% | 60.50% |  6.00% |  1.50% | 100.00% |  30.50% |  50.00% |  99.00% | 79.50% | 87.50% |  5.00% | 100.00% | 25.50% | 95.50% | 93.00% | 17.50% | 96.00% |   3.00% | 93.50% | 90.50% | 97.50% | 99.00% | 82.50% |  98.00% | 99.50% | 96.50% | 84.50% | 96.50% | 40.50% | 88.50% | 95.50% | 40.50% | 85.50% | 97.50% | 98.50% |   3.00% | 94.00% | 96.00% | 96.50% | 86.50% | 98.00% |  96.50% | 96.50% | 97.50% | 100.00% |
# | detector_ngram2 |  93.40% | 99.50% | 99.00% | 100.00% | 96.00% | 100.00% | 86.00% | 79.00% | 88.00% | 100.00% |  98.50% |  86.00% |  99.50% | 99.00% | 95.50% |  3.50% | 100.00% | 76.00% | 98.00% | 94.00% | 86.50% | 98.00% |  91.50% | 95.00% | 96.50% | 97.00% | 99.00% | 97.00% | 100.00% | 95.50% | 97.00% | 99.00% | 99.00% | 94.50% | 95.00% | 97.50% | 90.00% | 87.00% | 99.50% | 97.00% |  87.00% | 98.00% | 98.00% | 97.00% | 98.50% | 98.50% |  98.00% | 95.50% | 97.00% | 100.00% |
# | detector_ngram3 |  95.76% | 99.50% | 99.50% | 100.00% | 98.00% | 100.00% | 94.50% | 91.50% | 95.50% | 100.00% | 100.00% |  98.50% | 100.00% | 99.00% | 99.00% | 11.50% | 100.00% | 83.50% | 98.50% | 93.50% | 91.00% | 98.50% |  99.50% | 97.00% | 98.50% | 97.00% | 99.00% | 98.00% | 100.00% | 94.00% | 97.50% | 99.50% | 99.00% | 96.50% | 97.00% | 99.00% | 98.50% | 89.00% | 99.50% | 97.00% |  99.00% | 99.50% | 98.00% | 99.00% | 98.50% | 99.00% |  99.50% | 96.50% | 96.50% |  99.50% |
# | detector_ngram4 |  97.79% | 99.50% | 99.50% | 100.00% | 98.50% | 100.00% | 96.00% | 97.50% | 96.50% | 100.00% | 100.00% | 100.00% | 100.00% | 99.00% | 99.50% | 94.00% | 100.00% | 90.50% | 99.00% | 93.50% | 93.00% | 98.50% |  99.50% | 97.50% | 99.00% | 97.00% | 99.00% | 98.00% | 100.00% | 88.00% | 96.50% | 99.50% | 98.00% | 97.00% | 95.50% | 99.00% | 99.50% | 90.00% | 99.50% | 97.50% |  99.50% | 99.50% | 98.00% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 97.50% |  99.50% |
# | detector_ngram5 |  97.93% | 99.50% | 99.50% | 100.00% | 98.50% | 100.00% | 96.00% | 98.50% | 96.50% | 100.00% | 100.00% | 100.00% | 100.00% | 99.00% | 99.50% | 94.00% | 100.00% | 92.50% | 99.00% | 94.50% | 93.50% | 98.50% | 100.00% | 97.50% | 99.00% | 97.00% | 99.00% | 98.50% | 100.00% | 88.00% | 97.00% | 99.50% | 96.00% | 97.50% | 96.00% | 99.00% | 99.50% | 90.50% | 99.50% | 97.50% | 100.00% | 99.50% | 98.50% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 98.00% |  99.50% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x20, 0x39, 0x39, 0x2e, 0x35, 0x30, 0x25, 0x20, 0x7c, 0x0a])

# %%
showtable(WB, LANGS, threshold=0.5)
# Out:
# 50 columns in total, 38 columns left.
# |                 | Average | ara    | bel    | ben     | bul    | cat     | ces    | ell     | fas     | fin    | hau    | heb     | hun    | ido    | isl    | jpn    | kab    | kor    | kur    | lat    | lit     | mar    | mkd    | msa    | nds    | nor    | pol    | ron    | rus    | slk    | swa    | swe    | tat    | tgl    | tur    | ukr     | vie    | yid    | zho     |
# |-----------------|---------|--------|--------|---------|--------|---------|--------|---------|---------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|---------|
# | detector_ngram1 |  93.84% | 99.50% | 99.00% | 100.00% | 91.50% | 100.00% | 60.50% | 100.00% |  99.00% | 79.50% | 87.50% | 100.00% | 95.50% | 93.00% | 96.00% | 93.50% | 90.50% | 97.50% | 99.00% | 82.50% |  98.00% | 99.50% | 96.50% | 84.50% | 96.50% | 88.50% | 95.50% | 85.50% | 97.50% | 98.50% | 94.00% | 96.00% | 96.50% | 86.50% | 98.00% |  96.50% | 96.50% | 97.50% | 100.00% |
# | detector_ngram2 |  97.26% | 99.50% | 99.00% | 100.00% | 96.00% | 100.00% | 86.00% | 100.00% |  99.50% | 99.00% | 95.50% | 100.00% | 98.00% | 94.00% | 98.00% | 95.00% | 96.50% | 97.00% | 99.00% | 97.00% | 100.00% | 95.50% | 97.00% | 99.00% | 99.00% | 95.00% | 97.50% | 87.00% | 99.50% | 97.00% | 98.00% | 98.00% | 97.00% | 98.50% | 98.50% |  98.00% | 95.50% | 97.00% | 100.00% |
# | detector_ngram3 |  98.08% | 99.50% | 99.50% | 100.00% | 98.00% | 100.00% | 94.50% | 100.00% | 100.00% | 99.00% | 99.00% | 100.00% | 98.50% | 93.50% | 98.50% | 97.00% | 98.50% | 97.00% | 99.00% | 98.00% | 100.00% | 94.00% | 97.50% | 99.50% | 99.00% | 97.00% | 99.00% | 89.00% | 99.50% | 97.00% | 99.50% | 98.00% | 99.00% | 98.50% | 99.00% |  99.50% | 96.50% | 96.50% |  99.50% |
# | detector_ngram4 |  98.01% | 99.50% | 99.50% | 100.00% | 98.50% | 100.00% | 96.00% | 100.00% | 100.00% | 99.00% | 99.50% | 100.00% | 99.00% | 93.50% | 98.50% | 97.50% | 99.00% | 97.00% | 99.00% | 98.00% | 100.00% | 88.00% | 96.50% | 99.50% | 98.00% | 95.50% | 99.00% | 90.00% | 99.50% | 97.50% | 99.50% | 98.00% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 97.50% |  99.50% |
# | detector_ngram5 |  98.07% | 99.50% | 99.50% | 100.00% | 98.50% | 100.00% | 96.00% | 100.00% | 100.00% | 99.00% | 99.50% | 100.00% | 99.00% | 94.50% | 98.50% | 97.50% | 99.00% | 97.00% | 99.00% | 98.50% | 100.00% | 88.00% | 97.00% | 99.50% | 96.00% | 96.00% | 99.00% | 90.50% | 99.50% | 97.50% | 99.50% | 98.50% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 98.00% |  99.50% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x20, 0x39, 0x39, 0x2e, 0x35, 0x30, 0x25, 0x20, 0x7c, 0x0a])

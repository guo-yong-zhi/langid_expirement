# %%
# import Pkg; Pkg.add("Tables"); Pkg.add("MarkdownTables"); Pkg.add("DataFrames")

# %%
# using ProgressMeter
include("datasetloader.jl")
include("benchmark.jl")
# Out:
# showtable (generic function with 2 methods)

# %%
@show DEFAULT_LOGP
# Out:
# DEFAULT_LOGP = -10.905166741508964
# -10.905166741508964

# %%
WV = WikiDataSet("corpus/wikipedia/test", langs=LANGS)
TV = TatoebaDataset("corpus/tatoeba", "tatoeba_test.txt", langs=LANGS)
# Out:
# 521469-element TatoebaDataset:
#              "Pardonu, permesu al mi indiki tri erarojn en la supra artikolo." => "epo"
#                                           "Mi veturigos vin al la flughaveno." => "epo"
#                                                                  "Kio mankas?" => "epo"
#                                             "Aĥ, kiam ili renkontiĝos denove?" => "epo"
#  "Kiam mi estis infano, mi pasigis multajn horojn legante sola en mia ĉambro." => "epo"
#                                               "Ŝajnas, ke la trajno malfruas." => "epo"
#                                                                 "Venu rapide!" => "epo"
#                                                    "Li montris al mi albumon." => "epo"
#                                                              "Estis du kukoj." => "epo"
#                                       "Mia filo scipovas jam nombri ĝis cent." => "epo"
#                                                                                ⋮
#                                                       "Tohle pivo je výborné." => "ces"
#                                               "Musíš se řídit matčinou radou." => "ces"
#                                              "Tom potvrdil všechno, co řekli." => "ces"
#                                                         "Byl obnoven pořádek." => "ces"
#                                               "Medvědi jsou velmi nebezpeční." => "ces"
#                                      "Buď vděčný za to, že můžeš být s Tomem." => "ces"
#                                                 "Neštěstí nechodí nikdy samo." => "ces"
#                                                     "Problémem nejsou peníze." => "ces"
#                                          "Tom koupil několik bochníků chleba." => "ces"

# %%
# import Pkg; Pkg.add(["LanguageFinder", "LanguageDetect", "Languages"])

# %%
# import LanguageFinder: LanguageFind
# detector_lf(t) = LanguageFind(t, 0).lang
import LanguageDetect: detect
detector_ld(t) = first(detect(t)).language
import Languages: LanguageDetector, isocode
Languages_detector = LanguageDetector()
function detector_ls(t)
    l = Languages_detector(t) |> first
    if l == nothing
        return ""
    else
        return l |> isocode
    end
end
using Logging
Logging.disable_logging(Logging.Info)
# Out:
# LogLevel(1)

# %%
include("detector.jl")
detector_lh
# Out:
# WARNING: redefinition of constant TLANGS. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant WLANGS. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant LANGS. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant WLANGMAP. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant TLANGMAP. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant REV_WLANGMAP. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant REV_TLANGMAP. This may fail, cause incorrect answers, or produce other errors.
# detector_lh (generic function with 1 method)

# %% [markdown]
# ## tatoeba

# %%
TB = benchmark(
"detector_ngram1"=>t->detector_lh(t, ngram=1),
"detector_ngram2"=>t->detector_lh(t, ngram=2),
"detector_ngram3"=>t->detector_lh(t, ngram=3),
"detector_ngram4"=>t->detector_lh(t, ngram=4),
"detector_ngram5"=>detector_lh,
# "Languages.jl"=>detector_ls, 
# "LanguageDetect.jl"=>detector_ld,
 dataset=TV, languages=LANGS)
# Out:
# detector_ngram1
#  32.774230 seconds (40.47 M allocations: 3.161 GiB, 1.59% gc time, 0.82% compilation time)
# detector_ngram2 93.704689 seconds (63.23 M allocations: 5.854 GiB, 0.95% gc time, 0.08% compilation time)
# detector_ngram3
# 159.081330 seconds (85.08 M allocations: 8.258 GiB, 0.74% gc time, 0.05% compilation time)
# detector_ngram4223.553122 seconds (106.08 M allocations: 10.882 GiB, 0.67% gc time, 0.03% compilation time)
# detector_ngram5
# 294.307278 seconds (126.62 M allocations: 14.058 GiB, 0.52% gc time, 0.02% compilation time)
# 5-element Vector{Any}:
#  "detector_ngram1" => [0.9889075630252101, 0.9441997063142438, 1.0, 0.7548231511254019, 0.5913461538461539, 0.5107260726072608, 0.24733768464445208, 0.200289063754617, 1.0, 0.4166373549067886  …  0.1076296333551275, 0.7978187919463087, 0.7562452687358062, 0.8681626928471248, 0.8216577540106952, 0.8316935372743558, 0.7729547432550044, 0.9966273187183811, 0.9827586206896551, 1.0]
#  "detector_ngram2" => [0.9878991596638655, 0.9544787077826725, 1.0, 0.7765273311897106, 0.8485576923076923, 0.6754675467546755, 0.5211267605633803, 0.7628713666291954, 1.0, 0.8932245867041857  …  0.5311069758084797, 0.9370805369127517, 0.8720666161998486, 0.8934081346423562, 0.9475935828877006, 0.9215929447430068, 0.7882941688424717, 0.9966273187183811, 0.9873563218390805, 1.0]
#  "detector_ngram3" => [0.9902521008403361, 0.9618208516886931, 1.0, 0.8094855305466238, 0.90625, 0.8369086908690869, 0.7066300240467194, 0.956608318612494, 1.0, 0.9671671649665846  …  0.8288990594980636, 0.9765100671140939, 0.9299772899318698, 0.9116409537166901, 0.9783422459893049, 0.9710899820862615, 0.856396866840731, 0.9991568296795953, 0.9896551724137931, 1.0]
#  "detector_ngram4" => [0.9909243697478992, 0.9647577092511013, 1.0, 0.8231511254019293, 0.9110576923076923, 0.8897139713971397, 0.7935417382342838, 0.9825598201381083, 1.0, 0.9830284910306015  …  0.9017753860081477, 0.9807046979865772, 0.9466313398940197, 0.9186535764375876, 0.9858288770053476, 0.9799641725230812, 0.8848999129677981, 0.9991568296795953, 0.9896551724137931, 1.0]
#  "detector_ngram5" => [0.9909243697478992, 0.960352422907489, 1.0, 0.8295819935691319, 0.9134615384615384, 0.902915291529153, 0.8313294400549639, 0.9867994218724908, 1.0, 0.9866778051354204  …  0.9160589448272394, 0.9823825503355704, 0.9462528387585163, 0.9186535764375876, 0.9879679144385026, 0.9819209039548022, 0.8957789382071366, 0.9991568296795953, 0.9908045977011494, 1.0]

# %%
showtable(TB, LANGS)
# Out:
# |                 | Average | ara    | bel    | ben     | bul    | cat    | ces    | dan    | deu    | ell     | eng    | epo    | fas    | fin    | fra    | hau    | hbs    | heb    | hin    | hun    | ido    | ina    | isl    | ita    | jpn    | kab    | kor     | kur    | lat    | lit    | mar    | mkd    | msa    | nds    | nld    | nor    | pol    | por    | ron    | rus    | slk    | spa    | swa    | swe    | tat    | tgl    | tur    | ukr    | vie    | yid    | zho     |
# |-----------------|---------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|
# | detector_ngram1 |  71.32% | 98.89% | 94.42% | 100.00% | 75.48% | 59.13% | 51.07% | 24.73% | 20.03% | 100.00% | 41.66% | 52.00% | 97.65% | 71.49% | 15.25% | 71.40% |  1.42% | 96.32% | 71.26% | 68.83% | 93.06% | 23.64% | 93.67% |  9.51% | 99.91% | 81.46% | 100.00% | 98.24% | 64.08% | 82.66% | 78.58% | 93.80% | 71.46% | 69.09% | 49.22% | 66.98% | 90.91% | 45.64% | 83.05% | 80.44% | 85.94% | 10.76% | 79.78% | 75.62% | 86.82% | 82.17% | 83.17% | 77.30% | 99.66% | 98.28% | 100.00% |
# | detector_ngram2 |  86.53% | 98.79% | 95.45% | 100.00% | 77.65% | 84.86% | 67.55% | 52.11% | 76.29% | 100.00% | 89.32% | 67.27% | 98.38% | 94.74% | 79.45% | 96.24% |  2.72% | 97.24% | 75.59% | 92.64% | 95.87% | 83.97% | 97.29% | 67.83% | 99.95% | 95.94% | 100.00% | 98.72% | 89.09% | 93.67% | 77.84% | 92.09% | 92.57% | 91.53% | 88.80% | 84.01% | 97.40% | 79.18% | 89.96% | 84.18% | 92.69% | 53.11% | 93.71% | 87.21% | 89.34% | 94.76% | 92.16% | 78.83% | 99.66% | 98.74% | 100.00% |
# | detector_ngram3 |  91.87% | 99.03% | 96.18% | 100.00% | 80.95% | 90.62% | 83.69% | 70.66% | 95.66% | 100.00% | 96.72% | 88.06% | 98.90% | 98.33% | 94.54% | 98.08% |  7.64% | 98.58% | 74.41% | 96.98% | 94.56% | 94.06% | 98.49% | 93.25% | 99.95% | 98.84% | 100.00% | 98.88% | 93.99% | 98.18% | 76.97% | 86.30% | 96.62% | 95.82% | 95.37% | 88.06% | 98.63% | 94.06% | 94.16% | 89.16% | 94.97% | 82.89% | 97.65% | 93.00% | 91.16% | 97.83% | 97.11% | 85.64% | 99.92% | 98.97% | 100.00% |
# | detector_ngram4 |  93.30% | 99.09% | 96.48% | 100.00% | 82.32% | 91.11% | 88.97% | 79.35% | 98.26% | 100.00% | 98.30% | 96.69% | 99.12% | 98.65% | 96.86% | 98.53% | 24.10% | 99.11% | 74.41% | 97.98% | 91.74% | 95.72% | 99.10% | 96.43% | 99.96% | 99.12% | 100.00% | 98.72% | 94.28% | 98.95% | 76.86% | 80.00% | 97.40% | 96.37% | 96.77% | 87.95% | 98.86% | 96.81% | 95.73% | 91.50% | 94.74% | 90.18% | 98.07% | 94.66% | 91.87% | 98.58% | 98.00% | 88.49% | 99.92% | 98.97% | 100.00% |
# | detector_ngram5 |  93.64% | 99.09% | 96.04% | 100.00% | 82.96% | 91.35% | 90.29% | 83.13% | 98.68% | 100.00% | 98.67% | 97.58% | 99.27% | 98.80% | 97.31% | 98.72% | 36.80% | 99.19% | 76.51% | 98.14% | 90.99% | 95.30% | 98.94% | 96.76% | 99.96% | 99.13% | 100.00% | 98.88% | 94.20% | 99.08% | 75.25% | 74.16% | 97.69% | 96.70% | 96.92% | 85.98% | 98.93% | 97.18% | 95.79% | 91.50% | 94.17% | 91.61% | 98.24% | 94.63% | 91.87% | 98.80% | 98.19% | 89.58% | 99.92% | 99.08% | 100.00% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x31, 0x30, 0x30, 0x2e, 0x30, 0x30, 0x25, 0x20, 0x7c, 0x0a])

# %%
showtable(TB, LANGS, threshold=0.)
# Out:
# 50 columns in total, 50 columns left.
# |                 | Average | ara    | bel    | ben     | bul    | cat    | ces    | dan    | deu    | ell     | eng    | epo    | fas    | fin    | fra    | hau    | hbs    | heb    | hin    | hun    | ido    | ina    | isl    | ita    | jpn    | kab    | kor     | kur    | lat    | lit    | mar    | mkd    | msa    | nds    | nld    | nor    | pol    | por    | ron    | rus    | slk    | spa    | swa    | swe    | tat    | tgl    | tur    | ukr    | vie    | yid    | zho     |
# |-----------------|---------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|
# | detector_ngram1 |  71.32% | 98.89% | 94.42% | 100.00% | 75.48% | 59.13% | 51.07% | 24.73% | 20.03% | 100.00% | 41.66% | 52.00% | 97.65% | 71.49% | 15.25% | 71.40% |  1.42% | 96.32% | 71.26% | 68.83% | 93.06% | 23.64% | 93.67% |  9.51% | 99.91% | 81.46% | 100.00% | 98.24% | 64.08% | 82.66% | 78.58% | 93.80% | 71.46% | 69.09% | 49.22% | 66.98% | 90.91% | 45.64% | 83.05% | 80.44% | 85.94% | 10.76% | 79.78% | 75.62% | 86.82% | 82.17% | 83.17% | 77.30% | 99.66% | 98.28% | 100.00% |
# | detector_ngram2 |  86.53% | 98.79% | 95.45% | 100.00% | 77.65% | 84.86% | 67.55% | 52.11% | 76.29% | 100.00% | 89.32% | 67.27% | 98.38% | 94.74% | 79.45% | 96.24% |  2.72% | 97.24% | 75.59% | 92.64% | 95.87% | 83.97% | 97.29% | 67.83% | 99.95% | 95.94% | 100.00% | 98.72% | 89.09% | 93.67% | 77.84% | 92.09% | 92.57% | 91.53% | 88.80% | 84.01% | 97.40% | 79.18% | 89.96% | 84.18% | 92.69% | 53.11% | 93.71% | 87.21% | 89.34% | 94.76% | 92.16% | 78.83% | 99.66% | 98.74% | 100.00% |
# | detector_ngram3 |  91.87% | 99.03% | 96.18% | 100.00% | 80.95% | 90.62% | 83.69% | 70.66% | 95.66% | 100.00% | 96.72% | 88.06% | 98.90% | 98.33% | 94.54% | 98.08% |  7.64% | 98.58% | 74.41% | 96.98% | 94.56% | 94.06% | 98.49% | 93.25% | 99.95% | 98.84% | 100.00% | 98.88% | 93.99% | 98.18% | 76.97% | 86.30% | 96.62% | 95.82% | 95.37% | 88.06% | 98.63% | 94.06% | 94.16% | 89.16% | 94.97% | 82.89% | 97.65% | 93.00% | 91.16% | 97.83% | 97.11% | 85.64% | 99.92% | 98.97% | 100.00% |
# | detector_ngram4 |  93.30% | 99.09% | 96.48% | 100.00% | 82.32% | 91.11% | 88.97% | 79.35% | 98.26% | 100.00% | 98.30% | 96.69% | 99.12% | 98.65% | 96.86% | 98.53% | 24.10% | 99.11% | 74.41% | 97.98% | 91.74% | 95.72% | 99.10% | 96.43% | 99.96% | 99.12% | 100.00% | 98.72% | 94.28% | 98.95% | 76.86% | 80.00% | 97.40% | 96.37% | 96.77% | 87.95% | 98.86% | 96.81% | 95.73% | 91.50% | 94.74% | 90.18% | 98.07% | 94.66% | 91.87% | 98.58% | 98.00% | 88.49% | 99.92% | 98.97% | 100.00% |
# | detector_ngram5 |  93.64% | 99.09% | 96.04% | 100.00% | 82.96% | 91.35% | 90.29% | 83.13% | 98.68% | 100.00% | 98.67% | 97.58% | 99.27% | 98.80% | 97.31% | 98.72% | 36.80% | 99.19% | 76.51% | 98.14% | 90.99% | 95.30% | 98.94% | 96.76% | 99.96% | 99.13% | 100.00% | 98.88% | 94.20% | 99.08% | 75.25% | 74.16% | 97.69% | 96.70% | 96.92% | 85.98% | 98.93% | 97.18% | 95.79% | 91.50% | 94.17% | 91.61% | 98.24% | 94.63% | 91.87% | 98.80% | 98.19% | 89.58% | 99.92% | 99.08% | 100.00% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x31, 0x30, 0x30, 0x2e, 0x30, 0x30, 0x25, 0x20, 0x7c, 0x0a])

# %%
showtable(TB, LANGS, threshold=0.5)
# Out:
# 50 columns in total, 40 columns left.
# |                 | Average | ara    | bel    | ben     | bul    | cat    | ces    | ell     | epo    | fas    | fin    | hau    | heb    | hin    | hun    | ido    | isl    | jpn    | kab    | kor     | kur    | lat    | lit    | mar    | mkd    | msa    | nds    | nor    | pol    | ron    | rus    | slk    | swa    | swe    | tat    | tgl    | tur    | ukr    | vie    | yid    | zho     |
# |-----------------|---------|--------|--------|---------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|
# | detector_ngram1 |  83.10% | 98.89% | 94.42% | 100.00% | 75.48% | 59.13% | 51.07% | 100.00% | 52.00% | 97.65% | 71.49% | 71.40% | 96.32% | 71.26% | 68.83% | 93.06% | 93.67% | 99.91% | 81.46% | 100.00% | 98.24% | 64.08% | 82.66% | 78.58% | 93.80% | 71.46% | 69.09% | 66.98% | 90.91% | 83.05% | 80.44% | 85.94% | 79.78% | 75.62% | 86.82% | 82.17% | 83.17% | 77.30% | 99.66% | 98.28% | 100.00% |
# | detector_ngram2 |  91.34% | 98.79% | 95.45% | 100.00% | 77.65% | 84.86% | 67.55% | 100.00% | 67.27% | 98.38% | 94.74% | 96.24% | 97.24% | 75.59% | 92.64% | 95.87% | 97.29% | 99.95% | 95.94% | 100.00% | 98.72% | 89.09% | 93.67% | 77.84% | 92.09% | 92.57% | 91.53% | 84.01% | 97.40% | 89.96% | 84.18% | 92.69% | 93.71% | 87.21% | 89.34% | 94.76% | 92.16% | 78.83% | 99.66% | 98.74% | 100.00% |
# | detector_ngram3 |  94.22% | 99.03% | 96.18% | 100.00% | 80.95% | 90.62% | 83.69% | 100.00% | 88.06% | 98.90% | 98.33% | 98.08% | 98.58% | 74.41% | 96.98% | 94.56% | 98.49% | 99.95% | 98.84% | 100.00% | 98.88% | 93.99% | 98.18% | 76.97% | 86.30% | 96.62% | 95.82% | 88.06% | 98.63% | 94.16% | 89.16% | 94.97% | 97.65% | 93.00% | 91.16% | 97.83% | 97.11% | 85.64% | 99.92% | 98.97% | 100.00% |
# | detector_ngram4 |  94.81% | 99.09% | 96.48% | 100.00% | 82.32% | 91.11% | 88.97% | 100.00% | 96.69% | 99.12% | 98.65% | 98.53% | 99.11% | 74.41% | 97.98% | 91.74% | 99.10% | 99.96% | 99.12% | 100.00% | 98.72% | 94.28% | 98.95% | 76.86% | 80.00% | 97.40% | 96.37% | 87.95% | 98.86% | 95.73% | 91.50% | 94.74% | 98.07% | 94.66% | 91.87% | 98.58% | 98.00% | 88.49% | 99.92% | 98.97% | 100.00% |
# | detector_ngram5 |  94.74% | 99.09% | 96.04% | 100.00% | 82.96% | 91.35% | 90.29% | 100.00% | 97.58% | 99.27% | 98.80% | 98.72% | 99.19% | 76.51% | 98.14% | 90.99% | 98.94% | 99.96% | 99.13% | 100.00% | 98.88% | 94.20% | 99.08% | 75.25% | 74.16% | 97.69% | 96.70% | 85.98% | 98.93% | 95.79% | 91.50% | 94.17% | 98.24% | 94.63% | 91.87% | 98.80% | 98.19% | 89.58% | 99.92% | 99.08% | 100.00% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x31, 0x30, 0x30, 0x2e, 0x30, 0x30, 0x25, 0x20, 0x7c, 0x0a])

# %% [markdown]
# ## wikipedia

# %%
WB = benchmark(
"detector_ngram1"=>t->detector_lh(t, ngram=1),
"detector_ngram2"=>t->detector_lh(t, ngram=2),
"detector_ngram3"=>t->detector_lh(t, ngram=3),
"detector_ngram4"=>t->detector_lh(t, ngram=4),
"detector_ngram5"=>detector_lh,
# "Languages.jl"=>detector_ls, 
# "LanguageDetect.jl"=>detector_ld,
 dataset=WV, languages=LANGS)
# Out:
# detector_ngram1 17.646137 seconds (18.98 M allocations: 1.299 GiB, 0.98% gc time, 0.47% compilation time)
# detector_ngram2
#  15.524355 seconds (37.25 M allocations: 2.512 GiB, 2.39% gc time, 0.58% compilation time)
# detector_ngram3
#  29.871154 seconds (55.49 M allocations: 3.933 GiB, 1.56% gc time, 0.20% compilation time)
# detector_ngram4
#  50.969828 seconds (73.71 M allocations: 5.453 GiB, 1.27% gc time, 0.11% compilation time)
# detector_ngram5 75.897000 seconds (91.91 M allocations: 7.130 GiB, 1.01% gc time, 0.07% compilation time)
# 5-element Vector{Any}:
#  "detector_ngram1" => [0.995, 0.99, 1.0, 0.91, 1.0, 0.56, 0.06, 0.015, 1.0, 0.305  …  0.03, 0.94, 0.96, 0.97, 0.865, 0.98, 0.965, 0.965, 0.975, 1.0]
#  "detector_ngram2" => [0.995, 0.99, 1.0, 0.96, 1.0, 0.845, 0.765, 0.875, 1.0, 0.985  …  0.86, 0.985, 0.98, 0.97, 0.985, 0.985, 0.98, 0.955, 0.98, 1.0]
#  "detector_ngram3" => [0.995, 0.995, 1.0, 0.98, 1.0, 0.945, 0.93, 0.955, 1.0, 1.0  …  0.99, 0.995, 0.98, 0.99, 0.985, 0.99, 0.995, 0.965, 0.975, 0.995]
#  "detector_ngram4" => [0.995, 0.995, 1.0, 0.99, 1.0, 0.96, 0.965, 0.965, 1.0, 1.0  …  0.995, 0.995, 0.985, 0.99, 0.985, 0.99, 1.0, 0.965, 0.975, 0.995]
#  "detector_ngram5" => [1.0, 0.995, 1.0, 0.99, 1.0, 0.96, 0.975, 0.965, 1.0, 1.0  …  1.0, 0.995, 0.985, 0.99, 0.985, 0.99, 1.0, 0.965, 0.98, 0.995]

# %%
showtable(WB, LANGS)
# Out:
# |                 | Average | ara     | bel    | ben     | bul    | cat     | ces    | dan    | deu    | ell     | eng     | epo     | fas     | fin    | fra     | hau    | hbs    | heb     | hin    | hun    | ido    | ina    | isl    | ita     | jpn    | kab    | kor    | kur    | lat    | lit     | mar    | mkd    | msa    | nds    | nld    | nor    | pol    | por    | ron    | rus    | slk    | spa     | swa    | swe    | tat    | tgl    | tur    | ukr     | vie    | yid    | zho     |
# |-----------------|---------|---------|--------|---------|--------|---------|--------|--------|--------|---------|---------|---------|---------|--------|---------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|---------|
# | detector_ngram1 |  76.56% |  99.50% | 99.00% | 100.00% | 91.00% | 100.00% | 56.00% |  6.00% |  1.50% | 100.00% |  30.50% |  52.00% |  99.00% | 79.50% |       - | 88.00% |  5.00% | 100.00% | 72.00% | 95.50% | 92.00% | 17.50% | 96.00% |   4.00% | 93.50% | 90.50% | 98.00% | 99.00% | 82.50% |  98.00% | 92.00% | 96.00% | 84.50% | 96.50% | 40.50% | 88.50% | 95.50% | 42.50% | 85.50% | 97.50% | 98.50% |   3.00% | 94.00% | 96.00% | 97.00% | 86.50% | 98.00% |  96.50% | 96.50% | 97.50% | 100.00% |
# | detector_ngram2 |  93.62% |  99.50% | 99.00% | 100.00% | 96.00% | 100.00% | 84.50% | 76.50% | 87.50% | 100.00% |  98.50% |  87.00% |  99.50% | 99.00% |  95.00% | 96.00% |  3.50% | 100.00% | 92.00% | 98.50% | 94.50% | 85.50% | 98.00% |  92.50% | 95.00% | 96.50% | 97.00% | 99.00% | 97.00% | 100.00% | 89.50% | 97.50% | 99.00% | 99.00% | 94.50% | 96.00% | 97.50% | 90.00% | 87.00% | 99.00% | 97.00% |  86.00% | 98.50% | 98.00% | 97.00% | 98.50% | 98.50% |  98.00% | 95.50% | 98.00% | 100.00% |
# | detector_ngram3 |  95.93% |  99.50% | 99.50% | 100.00% | 98.00% | 100.00% | 94.50% | 93.00% | 95.50% | 100.00% | 100.00% |  98.50% | 100.00% | 99.00% | 100.00% | 99.00% |  6.50% | 100.00% | 92.50% | 98.50% | 94.00% | 91.50% | 98.50% |  99.50% | 97.50% | 98.50% | 97.00% | 99.00% | 98.00% | 100.00% | 88.00% | 99.00% | 99.50% | 99.00% | 96.50% | 97.50% | 99.00% | 99.00% | 89.00% | 99.50% | 97.00% |  99.00% | 99.50% | 98.00% | 99.00% | 98.50% | 99.00% |  99.50% | 96.50% | 97.50% |  99.50% |
# | detector_ngram4 |  97.95% |  99.50% | 99.50% | 100.00% | 99.00% | 100.00% | 96.00% | 96.50% | 96.50% | 100.00% | 100.00% | 100.00% | 100.00% | 99.00% | 100.00% | 99.50% | 93.00% | 100.00% | 93.00% | 99.00% | 94.00% | 92.50% | 98.50% | 100.00% | 97.50% | 99.00% | 97.00% | 99.00% | 98.00% | 100.00% | 88.50% | 98.00% | 99.50% | 99.00% | 97.00% | 96.50% | 99.00% | 99.50% | 90.00% | 99.50% | 97.50% |  99.50% | 99.50% | 98.50% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 97.50% |  99.50% |
# | detector_ngram5 |  98.06% | 100.00% | 99.50% | 100.00% | 99.00% | 100.00% | 96.00% | 97.50% | 96.50% | 100.00% | 100.00% | 100.00% | 100.00% | 99.00% | 100.00% | 99.50% | 94.00% | 100.00% | 92.00% | 99.00% | 94.50% | 95.00% | 98.50% | 100.00% | 98.00% | 99.00% | 97.00% | 99.00% | 98.50% | 100.00% | 88.50% | 96.50% | 99.50% | 98.50% | 97.50% | 96.50% | 99.00% | 99.50% | 90.50% | 99.50% | 97.50% | 100.00% | 99.50% | 98.50% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 98.00% |  99.50% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x20, 0x39, 0x39, 0x2e, 0x35, 0x30, 0x25, 0x20, 0x7c, 0x0a])

# %%
showtable(WB, LANGS, threshold=0.)
# Out:
# 50 columns in total, 49 columns left.
# |                 | Average | ara     | bel    | ben     | bul    | cat     | ces    | dan    | deu    | ell     | eng     | epo     | fas     | fin    | hau    | hbs    | heb     | hin    | hun    | ido    | ina    | isl    | ita     | jpn    | kab    | kor    | kur    | lat    | lit     | mar    | mkd    | msa    | nds    | nld    | nor    | pol    | por    | ron    | rus    | slk    | spa     | swa    | swe    | tat    | tgl    | tur    | ukr     | vie    | yid    | zho     |
# |-----------------|---------|---------|--------|---------|--------|---------|--------|--------|--------|---------|---------|---------|---------|--------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|---------|--------|--------|---------|
# | detector_ngram1 |  78.12% |  99.50% | 99.00% | 100.00% | 91.00% | 100.00% | 56.00% |  6.00% |  1.50% | 100.00% |  30.50% |  52.00% |  99.00% | 79.50% | 88.00% |  5.00% | 100.00% | 72.00% | 95.50% | 92.00% | 17.50% | 96.00% |   4.00% | 93.50% | 90.50% | 98.00% | 99.00% | 82.50% |  98.00% | 92.00% | 96.00% | 84.50% | 96.50% | 40.50% | 88.50% | 95.50% | 42.50% | 85.50% | 97.50% | 98.50% |   3.00% | 94.00% | 96.00% | 97.00% | 86.50% | 98.00% |  96.50% | 96.50% | 97.50% | 100.00% |
# | detector_ngram2 |  93.59% |  99.50% | 99.00% | 100.00% | 96.00% | 100.00% | 84.50% | 76.50% | 87.50% | 100.00% |  98.50% |  87.00% |  99.50% | 99.00% | 96.00% |  3.50% | 100.00% | 92.00% | 98.50% | 94.50% | 85.50% | 98.00% |  92.50% | 95.00% | 96.50% | 97.00% | 99.00% | 97.00% | 100.00% | 89.50% | 97.50% | 99.00% | 99.00% | 94.50% | 96.00% | 97.50% | 90.00% | 87.00% | 99.00% | 97.00% |  86.00% | 98.50% | 98.00% | 97.00% | 98.50% | 98.50% |  98.00% | 95.50% | 98.00% | 100.00% |
# | detector_ngram3 |  95.85% |  99.50% | 99.50% | 100.00% | 98.00% | 100.00% | 94.50% | 93.00% | 95.50% | 100.00% | 100.00% |  98.50% | 100.00% | 99.00% | 99.00% |  6.50% | 100.00% | 92.50% | 98.50% | 94.00% | 91.50% | 98.50% |  99.50% | 97.50% | 98.50% | 97.00% | 99.00% | 98.00% | 100.00% | 88.00% | 99.00% | 99.50% | 99.00% | 96.50% | 97.50% | 99.00% | 99.00% | 89.00% | 99.50% | 97.00% |  99.00% | 99.50% | 98.00% | 99.00% | 98.50% | 99.00% |  99.50% | 96.50% | 97.50% |  99.50% |
# | detector_ngram4 |  97.91% |  99.50% | 99.50% | 100.00% | 99.00% | 100.00% | 96.00% | 96.50% | 96.50% | 100.00% | 100.00% | 100.00% | 100.00% | 99.00% | 99.50% | 93.00% | 100.00% | 93.00% | 99.00% | 94.00% | 92.50% | 98.50% | 100.00% | 97.50% | 99.00% | 97.00% | 99.00% | 98.00% | 100.00% | 88.50% | 98.00% | 99.50% | 99.00% | 97.00% | 96.50% | 99.00% | 99.50% | 90.00% | 99.50% | 97.50% |  99.50% | 99.50% | 98.50% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 97.50% |  99.50% |
# | detector_ngram5 |  98.02% | 100.00% | 99.50% | 100.00% | 99.00% | 100.00% | 96.00% | 97.50% | 96.50% | 100.00% | 100.00% | 100.00% | 100.00% | 99.00% | 99.50% | 94.00% | 100.00% | 92.00% | 99.00% | 94.50% | 95.00% | 98.50% | 100.00% | 98.00% | 99.00% | 97.00% | 99.00% | 98.50% | 100.00% | 88.50% | 96.50% | 99.50% | 98.50% | 97.50% | 96.50% | 99.00% | 99.50% | 90.50% | 99.50% | 97.50% | 100.00% | 99.50% | 98.50% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 98.00% |  99.50% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x20, 0x39, 0x39, 0x2e, 0x35, 0x30, 0x25, 0x20, 0x7c, 0x0a])

# %%
showtable(WB, LANGS, threshold=0.5)
# Out:
# 50 columns in total, 40 columns left.
# |                 | Average | ara     | bel    | ben     | bul    | cat     | ces    | ell     | epo     | fas     | fin    | hau    | heb     | hin    | hun    | ido    | isl    | jpn    | kab    | kor    | kur    | lat    | lit     | mar    | mkd    | msa    | nds    | nor    | pol    | ron    | rus    | slk    | swa    | swe    | tat    | tgl    | tur    | ukr     | vie    | yid    | zho     |
# |-----------------|---------|---------|--------|---------|--------|---------|--------|---------|---------|---------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|--------|--------|---------|
# | detector_ngram1 |  91.94% |  99.50% | 99.00% | 100.00% | 91.00% | 100.00% | 56.00% | 100.00% |  52.00% |  99.00% | 79.50% | 88.00% | 100.00% | 72.00% | 95.50% | 92.00% | 96.00% | 93.50% | 90.50% | 98.00% | 99.00% | 82.50% |  98.00% | 92.00% | 96.00% | 84.50% | 96.50% | 88.50% | 95.50% | 85.50% | 97.50% | 98.50% | 94.00% | 96.00% | 97.00% | 86.50% | 98.00% |  96.50% | 96.50% | 97.50% | 100.00% |
# | detector_ngram2 |  96.79% |  99.50% | 99.00% | 100.00% | 96.00% | 100.00% | 84.50% | 100.00% |  87.00% |  99.50% | 99.00% | 96.00% | 100.00% | 92.00% | 98.50% | 94.50% | 98.00% | 95.00% | 96.50% | 97.00% | 99.00% | 97.00% | 100.00% | 89.50% | 97.50% | 99.00% | 99.00% | 96.00% | 97.50% | 87.00% | 99.00% | 97.00% | 98.50% | 98.00% | 97.00% | 98.50% | 98.50% |  98.00% | 95.50% | 98.00% | 100.00% |
# | detector_ngram3 |  97.90% |  99.50% | 99.50% | 100.00% | 98.00% | 100.00% | 94.50% | 100.00% |  98.50% | 100.00% | 99.00% | 99.00% | 100.00% | 92.50% | 98.50% | 94.00% | 98.50% | 97.50% | 98.50% | 97.00% | 99.00% | 98.00% | 100.00% | 88.00% | 99.00% | 99.50% | 99.00% | 97.50% | 99.00% | 89.00% | 99.50% | 97.00% | 99.50% | 98.00% | 99.00% | 98.50% | 99.00% |  99.50% | 96.50% | 97.50% |  99.50% |
# | detector_ngram4 |  98.08% |  99.50% | 99.50% | 100.00% | 99.00% | 100.00% | 96.00% | 100.00% | 100.00% | 100.00% | 99.00% | 99.50% | 100.00% | 93.00% | 99.00% | 94.00% | 98.50% | 97.50% | 99.00% | 97.00% | 99.00% | 98.00% | 100.00% | 88.50% | 98.00% | 99.50% | 99.00% | 96.50% | 99.00% | 90.00% | 99.50% | 97.50% | 99.50% | 98.50% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 97.50% |  99.50% |
# | detector_ngram5 |  98.07% | 100.00% | 99.50% | 100.00% | 99.00% | 100.00% | 96.00% | 100.00% | 100.00% | 100.00% | 99.00% | 99.50% | 100.00% | 92.00% | 99.00% | 94.50% | 98.50% | 98.00% | 99.00% | 97.00% | 99.00% | 98.50% | 100.00% | 88.50% | 96.50% | 99.50% | 98.50% | 96.50% | 99.00% | 90.50% | 99.50% | 97.50% | 99.50% | 98.50% | 99.00% | 98.50% | 99.00% | 100.00% | 96.50% | 98.00% |  99.50% |
# DisplayAs.Raw.Showable{MIME{Symbol("text/markdown")}}(UInt8[0x7c, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20, 0x20  …  0x20, 0x39, 0x39, 0x2e, 0x35, 0x30, 0x25, 0x20, 0x7c, 0x0a])
